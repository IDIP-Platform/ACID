# %%
# Import required modules
import numpy as np
import os
import pandas as pd
from skimage import io
from feature_extraction.measure_haralick import measure_haralick_features

# %%
from dask.distributed import Client, LocalCluster

# %%
cluster = LocalCluster(n_workers=8)
client = Client(cluster)
print(client)
# Out:
# <Client: 'tcp://127.0.0.1:42877' processes=8 threads=24, memory=62.71 GiB>
# BokehUserWarning: reference already known 'p1021'
# BokehUserWarning: reference already known 'p1146'
# BokehUserWarning: reference already known 'p1186'
# BokehUserWarning: reference already known 'p1424'
# BokehUserWarning: reference already known 'p1430'
# BokehUserWarning: reference already known 'p1488'
# BokehUserWarning: reference already known 'p1956'

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:42877' processes=8 threads=24, memory=62.71 GiB>

# %%
# Indicate the path to the input image
input_image___path = os.path.join(os.getcwd(),"secondary_output")
input_image___path = os.path.join("/home/kriedmiller/Downloads")

# get the name of the input image
input_image___name = "260202_fov_example.ome.tif"

# open input image
input_real_image = io.imread(os.path.join(input_image___path, input_image___name))
print(input_real_image.shape)

# the first image of the channel axis is the segmentation mask. The following images are channels, to be analysed
# Out:
# (2720, 2720, 7)

# %% [markdown]
# the file is a 2720x2720 field of view with 7 channels.
#
# The first of the 7 channels is the segmentation mask.
#
# Objects are individual cells.
#
# The remaining 6 channels are different imaged structures / imaging modalities.

# %%
# %pdb

# %%
real_data_haralick_features = measure_haralick_features(image=input_real_image[...,1:3],
                                             label_image=input_real_image[...,0],
                                             props=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation', 'ASM'],
                                             distances=[5, 15, 49],
                                             angles=[0, np.pi/4, np.pi/2, 3*np.pi/4],
                                             channel_axis=-1,
                                             window_shape=50,
                                             glcm_daskbag_kwargs={'npartitions': 10})

real_data_haralick_features

# single channel,, window_shape==50, 6 prop, 3 distance [5, 15, 49], 4 angles [0, np.pi/4, np.pi/2, 3*np.pi/4], 10 partitions -> 8m 16s
# double channels,, window_shape==50, 6 prop, 3 distance [5, 15, 49], 4 angles [0, np.pi/4, np.pi/2, 3*np.pi/4], 12 partitions -> 15m 33s
# Out:
# Default: Rescaling image to 8 intensity levels - indicate levels in glcm_graycomtx_kwargs to avoid this
# /home/kriedmiller/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/distributed/client.py:3387: UserWarning: Sending large graph of size 28.26 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py:750: FutureWarning: `RegionProperties.intensity_image` is deprecated starting in version 0.26 and will be removed in version 2.0. Use `RegionProperties.image_intensity` instead.
#   sub_image = region.intensity_image[..., channel_index]  # pick channel
# /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py:750: FutureWarning: `RegionProperties.intensity_image` is deprecated starting in version 0.26 and will be removed in version 2.0. Use `RegionProperties.image_intensity` instead.
#   sub_image = region.intensity_image[..., channel_index]  # pick channel
# /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py:750: FutureWarning: `RegionProperties.intensity_image` is deprecated starting in version 0.26 and will be removed in version 2.0. Use `RegionProperties.image_intensity` instead.
#   sub_image = region.intensity_image[..., channel_index]  # pick channel
# /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py:750: FutureWarning: `RegionProperties.intensity_image` is deprecated starting in version 0.26 and will be removed in version 2.0. Use `RegionProperties.image_intensity` instead.
#   sub_image = region.intensity_image[..., channel_index]  # pick channel
# /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py:750: FutureWarning: `RegionProperties.intensity_image` is deprecated starting in version 0.26 and will be removed in version 2.0. Use `RegionProperties.image_intensity` instead.
#   sub_image = region.intensity_image[..., channel_index]  # pick channel
# /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py:750: FutureWarning: `RegionProperties.intensity_image` is deprecated starting in version 0.26 and will be removed in version 2.0. Use `RegionProperties.image_intensity` instead.
#   sub_image = region.intensity_image[..., channel_index]  # pick channel
# /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py:750: FutureWarning: `RegionProperties.intensity_image` is deprecated starting in version 0.26 and will be removed in version 2.0. Use `RegionProperties.image_intensity` instead.
#   sub_image = region.intensity_image[..., channel_index]  # pick channel
# /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py:750: FutureWarning: `RegionProperties.intensity_image` is deprecated starting in version 0.26 and will be removed in version 2.0. Use `RegionProperties.image_intensity` instead.
#   sub_image = region.intensity_image[..., channel_index]  # pick channel
# 2026-02-16 15:15:08,065 - distributed.worker - ERROR - Compute Failed
# Key:       ('from_sequence-lambda-0449a8065926671c4620affd9f5b277c', 10)
# State:     executing
# Task:  <Task ('from_sequence-lambda-0449a8065926671c4620affd9f5b277c', 10) _execute_subgraph(...)>
# Exception: 'TypingError(\'Failed in nopython mode pipeline (step: nopython frontend)\\n\\x1b\\x1b\\x1bNo implementation of function Function(<built-in function setitem>) found for signature:\\n \\n >>> setitem(array(float64, 3d, C), array(bool, 3d, C), Literal[int](1))\\n \\nThere are 16 candidate implementations:\\n\\x1b  - Of which 14 did not match due to:\\n  Overload of function \\\'setitem\\\': File: <numerous>: Line N/A.\\n    With argument(s): \\\'(array(float64, 3d, C), array(bool, 3d, C), int64)\\\':\\x1b\\n\\x1b   No match.\\x1b\\n\\x1b  - Of which 2 did not match due to:\\n  Overload in function \\\'SetItemBuffer.generic\\\': File: numba/core/typing/arraydecl.py: Line 221.\\n    With argument(s): \\\'(array(float64, 3d, C), array(bool, 3d, C), int64)\\\':\\x1b\\n\\x1b   Rejected as the implementation raised a specific error:\\n     NumbaTypeError: \\x1bMulti-dimensional indices are not supported.\\x1b\\x1b\\n  raised from /home/kriedmiller/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/numba/core/typing/arraydecl.py:91\\n\\x1b\\n\\x1b\\x1bDuring: typing of setitem at /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py (601)\\x1b\\n\\x1b\\nFile "feature_extraction/measure_haralick.py", line 601:\\x1b\\n\\x1b    def glcm_mean(num_level):\\n        <source elided>\\n    glcm_sums = np.sum(P, axis=(0, 1), keepdims=True)\\n\\x1b    glcm_sums[glcm_sums == 0] = 1\\n\\x1b    \\x1b^\\x1b\\x1b\\n\\n\\x1b\\x1bDuring: Pass nopython_type_inference\\x1b\')'
# Traceback: '  File "/home/kriedmiller/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/dask/bag/core.py", line 1872, in reify\n    seq = list(seq)\n          ^^^^^^^^^\n  File "/home/kriedmiller/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/dask/bag/core.py", line 2072, in __next__\n    return self.f(*vals)\n           ^^^^^^^^^^^^^\n  File "/home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py", line 1128, in <lambda>\n    results = bag.map(lambda rc: glcm_object(rc[0],\n                                 ^^^^^^^^^^^^^^^^^^\n  File "/home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py", line 757, in glcm_object\n    fmap_local = glcm_feature_map(image=sub_image,\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py", line 485, in glcm_feature_map\n    prop_i = graycoprops(glcm, p)\n             ^^^^^^^^^^^^^^^^^^^^\n  File "/home/kriedmiller/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/numba/core/dispatcher.py", line 424, in _compile_for_args\n    error_rewrite(e, \'typing\')\n  File "/home/kriedmiller/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/numba/core/dispatcher.py", line 365, in error_rewrite\n    raise e.with_traceback(None)\n'
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 real_data_haralick_features = measure_haralick_features(image=input_real_image[...,1:3],
#       2                                              label_image=input_real_image[...,0],
#       3                                              props=['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation', 'ASM'],
#       4                                              distances=[5, 15, 49],
#       5                                              angles=[0, np.pi/4, np.pi/2, 3*np.pi/4],
#       6                                              channel_axis=-1,
#       7                                              window_shape=50,
#       8                                              glcm_daskbag_kwargs={'npartitions': 10})
#      10 real_data_haralick_features
#      12 # single channel,, window_shape==50, 6 prop, 3 distance [5, 15, 49], 4 angles [0, np.pi/4, np.pi/2, 3*np.pi/4], 10 partitions -> 8m 16s
#      13 # double channels,, window_shape==50, 6 prop, 3 distance [5, 15, 49], 4 angles [0, np.pi/4, np.pi/2, 3*np.pi/4], 12 partitions -> 15m 33s
#
# File ~/projects/ACID/feature_extraction/measure_haralick.py:1589, in measure_haralick_features(image, label_image, props, distances, angles, channel_axis, window_shape, regionprops_kwargs, erosion_kwargs, merge_kwargs, glcm_regionprops_kwargs, glcm_daskbag_kwargs, glcm_graycomtx_kwargs, glcm_pad_kwargs, glcm_windows_kwargs, glcm_zeros_kwargs, glcm_concat_kwargs, erosion_warning, sep)
#    1582 assert 'label' in regionprops_kwargs['properties'], "label must be in regionprops_kwargs['properties']"
#    1585 # calculate haralick feature maps
#    1586 # NOTE: the output haralick_feature_map has the same shape of original_image, plus 2 extra dimensions
#    1587 # in the second last position there is the channel axis (if no channel_axis is present in original_image,
#    1588 # this dimenstion is of size 1) and in the last position there is the haralick feature maps axis
# -> 1589 haralick_feature_map = parallel_glcm_feature_map(image=original_image,
#    1590                                                  label_image=original_label_image,
#    1591                                                  props=props,
#    1592                                                  distances=distances,
#    1593                                                  angles=angles,
#    1594                                                  channel_axis=ch_axis,
#    1595                                                  window_shape=window_shape,
#    1596                                                  regionprops_kwargs=glcm_regionprops_kwargs,
#    1597                                                  daskbag_kwargs=glcm_daskbag_kwargs,
#    1598                                                  graycomtx_kwargs=glcm_graycomtx_kwargs,
#    1599                                                  pad_kwargs=glcm_pad_kwargs,
#    1600                                                  windows_kwargs=glcm_windows_kwargs,
#    1601                                                  zeros_kwargs=glcm_zeros_kwargs,
#    1602                                                  concat_kwargs=glcm_concat_kwargs)
#    1604 # erode labels
#    1605 eroded_label_image = erosion(original_label_image, **erosion_kwargs)
#
# File ~/projects/ACID/feature_extraction/measure_haralick.py:1138, in parallel_glcm_feature_map(image, label_image, props, distances, angles, channel_axis, window_shape, regionprops_kwargs, daskbag_kwargs, graycomtx_kwargs, pad_kwargs, windows_kwargs, zeros_kwargs, concat_kwargs)
#    1124 labels.append("Build bag")
#    1127 # compute tasks in the dask.bag in parallel
#    1128 results = bag.map(lambda rc: glcm_object(rc[0],
#    1129                                          channel_index=rc[1],
#    1130                                          props=props,
#    1131                                          distances=distances,
#    1132                                          angles=angles,
#    1133                                          window_shape=window_shape,
#    1134                                          graycomtx_kwargs=graycomtx_kwargs,
#    1135                                          pad_kwargs=pad_kwargs,
#    1136                                          windows_kwargs=windows_kwargs,
#    1137                                          zeros_kwargs=zeros_kwargs,
# -> 1138                                          concat_kwargs=concat_kwargs)).compute()
#    1141 times.append(time() - times.pop())
#    1142 times.append(time())
#
# File ~/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/dask/base.py:377, in DaskMethodsMixin.compute(self, **kwargs)
#     353 def compute(self, **kwargs):
#     354     """Compute this dask collection
#     355
#     356     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    375     dask.compute
#     376     """
# --> 377     (result,) = compute(self, traverse=False, **kwargs)
#     378     return result
#
# File ~/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/dask/base.py:685, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     682     expr = expr.optimize()
#     683     keys = list(flatten(expr.__dask_keys__()))
# --> 685     results = schedule(expr, keys, **kwargs)
#     687 return repack(results)
#
# File ~/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/dask/bag/core.py:1872, in reify()
#    1870 def reify(seq):
#    1871     if isinstance(seq, Iterator):
# -> 1872         seq = list(seq)
#    1873     try:
#    1874         first = next(iter(seq))
#
# File ~/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/dask/bag/core.py:2072, in __next__()
#    2070     kwargs = dict(zip(self.kwarg_keys, vals[-self.nkws :]))
#    2071     return self.f(*args, **kwargs)
# -> 2072 return self.f(*vals)
#
# File ~/projects/ACID/feature_extraction/measure_haralick.py:1128, in parallel_glcm_feature_map.<locals>.<lambda>()
#    1124 labels.append("Build bag")
#    1127 # compute tasks in the dask.bag in parallel
# -> 1128 results = bag.map(lambda rc: glcm_object(rc[0],
#    1129                                          channel_index=rc[1],
#    1130                                          props=props,
#    1131                                          distances=distances,
#    1132                                          angles=angles,
#    1133                                          window_shape=window_shape,
#    1134                                          graycomtx_kwargs=graycomtx_kwargs,
#    1135                                          pad_kwargs=pad_kwargs,
#    1136                                          windows_kwargs=windows_kwargs,
#    1137                                          zeros_kwargs=zeros_kwargs,
#    1138                                          concat_kwargs=concat_kwargs)).compute()
#    1141 times.append(time() - times.pop())
#    1142 times.append(time())
#
# File ~/projects/ACID/feature_extraction/measure_haralick.py:757, in glcm_object()
#     754 mask = region.image
#     756 # Compute glcm_feature_map for the region/segmented object
# --> 757 fmap_local = glcm_feature_map(image=sub_image,
#     758                               mask=mask,
#     759                               props=props,
#     760                               distances=distances,
#     761                               angles=angles,
#     762                               window_shape=window_shape,
#     763                               graycomtx_kwargs=graycomtx_kwargs,
#     764                               pad_kwargs=pad_kwargs,
#     765                               windows_kwargs=windows_kwargs,
#     766                               zeros_kwargs=zeros_kwargs,
#     767                               concat_kwargs=concat_kwargs)
#     769 return (region.label, region.bbox, channel_index, fmap_local)
#
# File ~/projects/ACID/feature_extraction/measure_haralick.py:485, in glcm_feature_map()
#     482 # Iterate through the properties to measure:
#     483 for p in props:
#     484     # Get the haralick measurement for all distances and angles
# --> 485     prop_i = graycoprops(glcm, p)
#     487     # Flatten the value
#     488     prop = prop_i.flatten()
#
# File ~/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/numba/core/dispatcher.py:424, in _compile_for_args()
#     420         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     421                f"by the following argument(s):\n{args_str}\n")
#     422         e.patch_message(msg)
# --> 424     error_rewrite(e, 'typing')
#     425 except errors.UnsupportedError as e:
#     426     # Something unsupported is present in the user code, add help info
#     427     error_rewrite(e, 'unsupported_error')
#
# File ~/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/numba/core/dispatcher.py:365, in error_rewrite()
#     363     raise e
#     364 else:
# --> 365     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# No implementation of function Function(<built-in function setitem>) found for signature:
#
#  >>> setitem(array(float64, 3d, C), array(bool, 3d, C), Literal[int](1))
#
# There are 16 candidate implementations:
#   - Of which 14 did not match due to:
#   Overload of function 'setitem': File: <numerous>: Line N/A.
#     With argument(s): '(array(float64, 3d, C), array(bool, 3d, C), int64)':
#    No match.
#   - Of which 2 did not match due to:
#   Overload in function 'SetItemBuffer.generic': File: numba/core/typing/arraydecl.py: Line 221.
#     With argument(s): '(array(float64, 3d, C), array(bool, 3d, C), int64)':
#    Rejected as the implementation raised a specific error:
#      NumbaTypeError: Multi-dimensional indices are not supported.
#   raised from /home/kriedmiller/software/miniforge3/envs/acid_develop/lib/python3.12/site-packages/numba/core/typing/arraydecl.py:91
#
# During: typing of setitem at /home/kriedmiller/projects/ACID/feature_extraction/measure_haralick.py (601)
#
# File "feature_extraction/measure_haralick.py", line 601:
#     def glcm_mean(num_level):
#         <source elided>
#     glcm_sums = np.sum(P, axis=(0, 1), keepdims=True)
#     glcm_sums[glcm_sums == 0] = 1
#     ^
#
# During: Pass nopython_type_inference

# %%
1
