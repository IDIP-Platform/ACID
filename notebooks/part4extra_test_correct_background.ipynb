# %% [markdown]
# ### **ACID - PART 4b - Test correct background illumination**
#
# # --- --- ---
#
# ### This notebook tests the use of a saved background function generated on part 4a notebook using a train set of data to correct for illumination artifacts on unseen data (test data).
#
# # --- --- ---
#
# **Author:** Alessandro Ulivi (alessandro.ulivi.89@gmail.com)
#
# **Last update (yyyy/mm/dd):** 2026/03/20

# %% [markdown]
# ## **---------------------------**

# %% [markdown]
# ### Import required modules
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# Import required modules
import datetime
import os

from pathlib import Path
import numpy as np
import pandas as pd
import tifffile
import matplotlib.pyplot as plt
from acid.utils.listdirNHF import listdirNHF
from acid.utils.get_defaults import default_file_name, default_multifile_name
from acid.utils.fov_axis_utils import get_fov_ch_shape
from acid.utils.save_image import tifffile_save_ometiff
from acid.utils.miscellaneous_utils import map_image_to_condition
from acid.image_processing.extract_metadata import extract_ometif_imagej_metadata
from acid.image_processing.make_imagej_metadata import imagej_compatible_metadata_dict
from acid.image_processing.correct_background import correct_background
from acid.image_visualization.display_illumination_correction import (
    plot_image_channels_and_diagonals,
)

# %% [markdown]
# ### Specify the paths to input and output data directories - specify hyperparameters
#
# Run the following cell.
#
# Some parts of the following cell should be modified. The parts NOT to modify are under the line ""--- --- --- DON'T MODIFY THE FOLLOWING LINES --- --- ---"

# %%
# background function computation strategy - this is the strategy used in part4a notebook for
# calculating the background function. Possible options are: 1,2,3.
# 1 - calculate a  background function per channel using all the fields of view in the dataset which are not flagged
# 2 - calculate a background function per each channel and well using the fields of view in the train set which are not
# flagged and belong to the well
# 3 - calculate a background function per each channel and grid position using the fields of view in the train set which are
# not flagged and belong to the same position (aka grid position) across different wells
background_function_strategy = 1

# indicate the path to the directory storing the background function images
# background_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\data\proc\background"
background_directory = Path.cwd().parent / "data" / "raw" / "proc" / "background"

# indicate the path to the directory storing the metadata file - NOTE: this is expected to be the metadata_df saved
# from either part4a or part3 notebook
# metadata_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\data\proc\proc_metadata"
metadata_directory = Path.cwd().parent / "data" / "raw" / "proc" / "proc_metadata"
# metadata_directory = r"C:\Users\aless\OneDrive\Desktop\Ale\lab\CIID_IDIP\projects\ACID\data\proc\proc_metadata"

# indicate the path to the directory storing the fields of view
# fov_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\data\proc\fov"
fov_directory = Path.cwd().parent / "data" / "raw" / "proc" / "fov"
# fov_directory = r"C:\Users\aless\OneDrive\Desktop\Ale\lab\CIID_IDIP\projects\ACID\data\proc\fov"

# # indicate the path to the directory where outputs will be saved
# NOTE: it the directory does not exist, the pipeline will try to create it
# output_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\data\proc\fov_proc"
output_directory = Path.cwd().parent / "data" / "raw" / "proc" / "fov_proc"
# output_directory = r"C:\Users\aless\OneDrive\Desktop\Ale\lab\CIID_IDIP\projects\ACID\data\proc\fov_proc"


# name of the metadata file - NOTE: this is expected to be the metadata_df saved
# from part3 notebook
# the following options are possible:
# 1) write the full name (extension included) of the csv file
# 2) write "default" or any other version with a uppercase letter (e.g. "Default")
# 3) leave an empty string: ""
# 4) write None (NOTE that this is not a string, there are no "", aka it is not "None")
# Options 2,3 and 4 will lead to the same behavior: the most recently saved csv file will be used.
# By default, the timestamp of the last file modification is used. As an alternative it is possible to use the
# date saved in the name (change below parameter metadata_from_file_name to True -
# see utils.get_defaults.default_file_name documentation).
# metadata_file_name = "20260707_ACID_metadata_part_2.csv"
metadata_file_name = "default"

# the timestamp (aka the date) present in the file name of the background function image. This is used for selecting the
# background function image to use for the illumination correction in part4b notebook.

# the following options are possible:
# 0) ONLY POSSIBLE FOR STRATEGY 1 - write the full name (extension included) of the background function image file.
# In this case, the file will be selected based on the name and not on the timestamp.
# 1) write the timestamp (aka the date) as a string (e.g. "20251126"). NOTE: the string must match the exact format
# used for in the file name. For example, if the file name is "251126_plate_layout.csv",
# the timestamp string should be "251126" and not "20251126".
# ALSO NOTE: that the if strategy is 1, only a single file with the timestamp in the name is expected in the
# background function directory. If strategy 2 or 3 are selected, a number of files
# corresponding to the number of wells or grid positions, respectively, are expected.
# 2) write "default" or any other version with a uppercase letter (e.g. "Default")
# 3) leave an empty string: ""
# 4) write None (NOTE that this is not a string, there are no "", aka it is not "None")
# Options 2,3 and 4 will lead to the same behavior: the most recently saved ome.tif files will be used.
# By default, the timestamp of the last file modification is used. As an alternative it is possible to use the
# date saved in the name (change below parameter metadata_from_file_name to True -
# see utils.get_defaults.default_file_name documentation).
# TECHNICAL NOTE: the use of the timestamp is not strictly necessary. In particular: any string which allows to
# uniquely identify the file(s) to use for the background function can be used.
background_function_timestamp = "default"

# indicate whether to save the graphs generated in this notebook
save_graphs = True

# graph saving directory - this is the directory where the graphs generated in this notebook will be saved
# graph_saving_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\develop\260319_illumination_correction\test"
graph_saving_directory = (
    Path.cwd().parent / "data" / "raw" / "proc" / "illumination_correction" / "test"
)


# ""--- --- --- DON'T MODIFY THE FOLLOWING LINES --- --- ---"
# # --- parameters to select the train set ---
# indicate the name of the column indicating whether the row belongs to train or test set
is_train_column = "is_train"

# indicate the value signalling that a row (aka a field of view) belongs to the train set
test_val = 1


# # --- parameters used for importing the default background function ---
# Indicate the part of the file name to use to select files into background_directory to be used for selecting the default
# file
default_bg_funct_file_target = ".ome.tif"  # files with this string in their name will be selected for the default file selection - if None, all files will be selected
default_bg_funct_file_exclude = None  # files with this string in their name will be excluded from the default file selection - if None, no files will be excluded

# Indicate whether to extract the date information from the file name when selecting the default file
# If False, the date will be extracted from the file's last modified timestamp, if True, from the file name.
# If from_file_name is True, the parameters *_default_separator and *_default_date_position
# should be used to indicate, respectively the separator to use for splitting the file name into tokens and
# the position of the token containing the date information. In addition, the date format used to include the date in the file name
# should be indicated using the parameters *_default_date_format.
# For example, if background_from_file_name is True, and the file name is "251126_plate_layout.csv",
# "_" is used as separator, 0 as date position, and '%Y%m%d' as date format.
# Ref to utils.get_defaults.default_file_name for more details.
background_from_file_name = False  # if False, the date will be extracted from the file's last modified timestamp, if True, from the file name.

# separator - used to split the file name and extract the information token with the date
# if background_from_file_name is True
background_default_separator = "_"

# date position - the position of the date information token after splitting the file name using file_name_separator (above)
# used if background_from_file_name is True
background_default_date_position = 0

# date format - the format used for including the date in the file name to be opened by default
# used if background_from_file_name is True
background_default_date_format = "%Y%m%d"

# reverse - if True, the file with the most recent date will be returned by default - if False, the opposite
background_default_reverse = True

# assert file number - this indicates whether to assert that the number of files matching the
# default file selection criteria is exactly one.
# If True, an assertion error will be raised if the number of files matching the criteria
# is not exactly one. If False, no assertion will be made and the function will return all the files
# matching the default file selection criteria. It is recommended to set this parameter to True when
# background_function_strategy is 1, since in this case only one background function file is expected to
# be used for the illumination correction. When background_function_strategy is 2 or 3, it is recommended
# to set this
background_default_assert_file_number = True
background_default_number_of_files_expected = 1


# # --- parameters used for importing the default metadata dataframe ---
# Indicate the part of the file name to use to select files into metadata_directory to be used for selecting the default
# file
default_metadata_file_target = ".csv"  # files with this string in their name will be selected for the default file selection - if None, all files will be selected
default_metadata_file_exclude = None  # files with this string in their name will be excluded from the default file selection - if None, no files will be excluded

# Indicate whether to extract the date information from the file name when selecting the default file
# If False, the date will be extracted from the file's last modified timestamp, if True, from the file name.
# If from_file_name is True, the parameters *_default_separator and *_default_date_position
# should be used to indicate, respectively the separator to use for splitting the file name into tokens and
# the position of the token containing the date information. In addition, the date format used to include the date in the file name
# should be indicated using the parameters *_default_date_format.
# For example, if metadata_from_file_name is True, and the file name is "251126_plate_layout.csv",
# "_" is used as separator, 0 as date position, and '%Y%m%d' as date format.
# Ref to utils.get_defaults.default_file_name for more details.
metadata_from_file_name = False

# separator - used to split the file name and extract the information token with the date
# if metadata_from_file_name is True
metadata_default_separator = "_"

# date position - the position of the date information token after splitting the file name using file_name_separator (above)
# used if metadata_from_file_name is True
metadata_default_date_position = 0

# date format - the format used for including the date in the file name to be opened by default
# used if metadata_from_file_name is True
metadata_default_date_format = "%Y%m%d"

# reverse - if True, the file with the most recent date will be returned by default - if False, the opposite
metadata_default_reverse = True


# --- parameters for background illumination correction ---
# channel axis to be passed to background calculating functions in order to calculate background functions per channel
# this is the axis along which the channels are organized in the field of view arrays.
# For example, if the field of view arrays have shape (channels, height, width), the channel axis is 0.
channel_axis = 0

# # data type to use for computing the illumination correction - the illumination correction is computed by
# # dividing the original field of view by a normalized background function. The data type to use for the field of view
# # when computing the division can be set here. It is recommended to use a floating point data type
# # (e.g. np.float32) to avoid issues with integer division and to preserve the precision of the background function.
# correction_operation_dtype_fov = np.float64

# # data type to use for computing the illumination correction - the illumination correction is computed by
# # dividing the original field of view by a normalized background function. The data type to use for the background
# # function when normalizing the histogram values and when computing the division can be set here. It is recommended
# # to use a floating point data type (e.g. np.float32) to avoid issues with integer division and to preserve the
# # precision of the background function.
# correction_operation_dtype_bg = np.float64

# the method used for illumination correction - this can be either "subtraction" or "division"
# method="subtraction"
method = "division"

# the offset to subtract from the image before correcting for the illumination
offset = 400

# the small constant to add to the background in oder to avoid zero numbers in the background function, which
# would lead to mathematical instability (e.g. division by zero)
epsilon = 1e-8

# the data type of the image corrected for illumination
output_dtype = np.float32
# output_dtype=np.int16

# the data type to use for the mathematical operations (subtraction and division) during illumination correction.
# NOTE: the same data type is used for both the image to correct and the background function
working_dtype = np.float32
# working_dtype = np.int16

# whether or not to rescale the background function before carrying out illumination correction.
# Three options are available:
# 1) None -> no rescaling is done.
# 2) "max" -> the background function is divided by the max value. The resulting, normalized background function has 1 as max value.
# 3) "minmax" -> the background function is min-max normalized (background - min) / (max - min + epsilon)
rescale_background = "max"

# whether or not to clip the image corrected for illumination. This is a boolean variable, it can be True or False.
# If True, the image after illumination correction is clipped in the min_clip_value, max_clip_value range.
# For example: when subtraction is use the result can contain negative values. It is possible to set them to 0
# by setting clip_corrected_image=True and min_clip_value=0 (irrespective of the max_clip_value)
clip_corrected_image = False

# the min value to which illumination corrected image is clipped to if clip_corrected_image is set to True
min_clip_value = 0

# the max value to which illumination corrected image is clipped to if clip_corrected_image is set to True
max_clip_value = None

# whether or not to offset the background function before carrying out illumination correction.
# Two options are available: True or False
offset_background = True

# additional parameters to pass to the initial container of the illumation corrected image during the correction process
# ref to the function correct_background within the image_processing.correct_background.py script for further details.
zero_kwargs = None

# select if printing process information during background correction
verbose = True

# field of view column name in the metadata dataframe
fov_column_name = "ome_tif_file_name"

# well column name in the metadata dataframe
well_column_name = "well"

# # plate column name in the metadata dataframe
# plate_column_name = "experiment"

# within well position column name in the metadata dataframe
# this is used to identify the position of the field of view within the well
# 49 fields of view were acquired per each well, in a 7x7 grid
gridpos_column_name = "scene_name"

# what is expected to be and what will be used as null value
null_value = np.nan


# --- parameters for saving metadata within the saved fields of view after illumination correction ---
# illumination correction image - name of processing date in metadata - this is the name
# of the entry in the metadata dictionary to save within the processed image.
# The entry indicates the date when the background correction was done.
proc_img_meta_date_name = "processing_date_yymmdd"

# illumination correction image - date format in metadata - this is the format to use for indicating
# the date when the background correction was done in the metadata saved within the processed image
processing_date_format = "%y%m%d"

# illumination correction image - data type in metadata - this is the entry to use for indicating
# the data type of the illumination corrected image in the metadata saved within the processed image
proc_img_meta_dtype_name = "dtype"

# illumination correction image - illumination correction method in metadata - this is the entry to use for indicating
# the method used for illumination correction in the metadata saved within the processed image
illum_corr_method_metadata_entry = "illumination_correction_method"

# illumination correction image - illumination correction offset in metadata - this is the entry to use for indicating
# the offset used for illumination correction in the metadata saved within the processed image
illum_corr_offset_metadata_entry = "illumination_correction_offset"

# illumination correction image - illumination correction rescaling in metadata - this is the entry to use for indicating
# in the metadata saved within the processed image, whether or not the background function is rescaled when doing illumination correction
illum_corr_rescale_metadata_entry = "illumination_correction_rescale_background"

# illumination correction image - illumination correction clipping in metadata - this is the entry to use for indicating
# in the metadata saved within the processed image, whether or not the illumination corrected image is clipped
illum_corr_clipping_metadata_entry = "illumination_correction_clipping"

# illumination correction image - illumination correction clipping min value in metadata - this is the entry to use for
# indicating in the metadata saved within the processed image, what was the min value used for clipping (if clipping was performed)
illum_corr_clip_min_value_metadata_entry = "illumination_correction_min_clip_value"

# illumination correction image - illumination correction clipping max value in metadata - this is the entry to use for
# indicating in the metadata saved within the processed image, what was the max value used for clipping (if clipping was performed)
illum_corr_clip_max_value_metadata_entry = "illumination_correction_max_clip_value"

# illumination correction image - illumination correction offset_background in metadata - this is the entry to use for
# indicating in the metadata saved within the processed image, if the offset is subtracted to the background function
illum_corr_offset_background_metadata_entry = (
    "illumination_correction_offset_background"
)

# indicate the photometric interpretation to be used when saving the ome.tif files
# NOTE: at the moment, only 'minisblack' has been tested
photometric = "minisblack"

# indicate whether to save the background function image with ImageJ compatible
save_imagej_compatible = True


# --- parameters for metadata dataframe updating ---
# column name word separator - this is the separator to use for separating the different parts of
# the column names to be added to the metadata dataframe
column_name_separator = "_"

# channel name separator - this is the separator to use for separating the channel name from the rest of
# the column name to be added to the metadata dataframe.
ch_name_separator = "-"

# illumination correction metadata dataframe - computation date column name - this is the name of the column
# to be added to the metadata dataframe to indicate the day when the illumination correction was computed.
illum_correct_df_date_clm_name = (
    f"illumination{column_name_separator}correction{column_name_separator}date"
)

# illumination correction metadata dataframe - computation date format - this is the format to be used for
# indicating the date when the illumination correction was computed. This is used for saving the date in the
# metadata dataframe
illum_correct_df_meta_date_format = "%y%m%d"

# illumination correction metadata dataframe - corrected file column name - this is the name of the column
# to be added to the metadata dataframe to indicate the name used for saving the illumination corrected file.
illum_correct_df_file_name_clm_name = f"illumination{column_name_separator}correction{column_name_separator}file{column_name_separator}name"

# illumination correction metadata dataframe - method for illumination correction column name - this is the name
# of the column to be added to the metadata dataframe to indicate the method used for illumination correction.
illum_correct_df_method_clm_name = (
    f"illumination{column_name_separator}correction{column_name_separator}method"
)

# illumination correction metadata dataframe - offset for illumination correction column name - this is the name
# of the column to be added to the metadata dataframe to indicate the offset used for illumination correction.
illum_correct_df_offset_clm_name = (
    f"illumination{column_name_separator}correction{column_name_separator}offset"
)

# illumination correction metadata dataframe - rescale for illumination correction column name - this is the name
# of the column to be added to the metadata dataframe to indicate if the background function was rescaled when
# doing illumination correction and the method used
illum_correct_df_rescale_clm_name = f"illumination{column_name_separator}correction{column_name_separator}rescale{column_name_separator}background"

# illumination correction metadata dataframe - clipping for illumination correction column name - this is the name
# of the column to be added to the metadata dataframe to indicate if doing illumination correction the corrected image
# has been clipped.
illum_correct_df_clipping_clm_name = f"illumination{column_name_separator}correction{column_name_separator}clip{column_name_separator}output"

# illumination correction metadata dataframe - clipping min value for illumination correction column name - this is
# the name of the column to be added to the metadata dataframe to indicate what was the minimum value used
# for clipping the corrected image (if clipping was done).
illum_correct_df_clip_min_value_clm_name = f"illumination{column_name_separator}correction{column_name_separator}min{column_name_separator}clip{column_name_separator}value"

# illumination correction metadata dataframe - clipping max value for illumination correction column name - this is
# the name of the column to be added to the metadata dataframe to indicate what was the maximum value used
# for clipping the corrected image (if clipping was done).
illum_correct_df_clip_max_value_clm_name = f"illumination{column_name_separator}correction{column_name_separator}max{column_name_separator}clip{column_name_separator}value"

# illumination correction metadata dataframe - offset_background for illumination correction column name - this is
# the name of the column to be added to the metadata dataframe to indicate if doing illumination correction the
# background function has been offsetted.
illum_correct_df_offset_background_clm_name = f"illumination{column_name_separator}correction{column_name_separator}offset{column_name_separator}background"


# --- parameters for file saving ---
# separator used for saved file names
save_file_name_separator = "_"

# project
project_name = "ACID"

# include indexes when saving pandas dataframes as csv files
save_csv_index = (
    False  # if False, the index will not be saved as a separate column in the csv file
)

# illumination correction image name - savingword - this is the word to use in the field of view file name
# to indicate that the file is an illumination corrected field of view
fov_illumin_corrected_savingword = "bg"

# ome suffix - used to save ome.tif files
ome_suffix = ".ome.tif"

# processing metadata dataframe name - savingword
metadata_savingword = "metadata"

# processing metadata dataframe name - file suffix
metadata_file_suffix = f"part{save_file_name_separator}4extra.csv"

# processing metadata dataframe name - date format
metadata_date_format = "%Y%m%d"

# hyperparameters dataframe name - date format
hyperparameters_date_format = "%Y%m%d-%H%M%S"

# hyperparameters dataframe name - savingword
hyperparameters_savingword = "hyperparameters"

# hyperparameters dataframe name - file suffix
hyperparameters_file_suffix = f"part{save_file_name_separator}4extra.csv"


# --- parameters for displaying the results ---
# graph saving date format
graph_date_format = "%Y%m%d"

# graphs suffix
graph_suffix = f".png"

# graph savingword
graph_savingword = f"illumination{save_file_name_separator}correction"


# --- parameters for saving secondary information ---
# indicate the name of the directory for saving secondary outputs -
# this directory is used to store the hyperparameters used per each run of the pipeline
secondary_output_directory = "secondary_output"
exist_ok = (
    True  # if the secondary output directory already exists, do not raise an error
)

# %% [markdown]
# ### Create output directory and secondary output directory if they don't exist
#
# ##### Output directory stores the computed background function
# ##### Secondary output directory is used to store the hyperparameters used per each run of the pipeline
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# create the output_directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory, exist_ok=exist_ok)

# create the path to secondary_output directory
secondary_output_path = os.path.join(os.getcwd(), secondary_output_directory)

# create the secondary_output directory if it doesn't exist
if not os.path.exists(secondary_output_path):
    os.makedirs(secondary_output_path, exist_ok=exist_ok)

# %% [markdown]
# #### Open the metadata dataframe - this is expected to be the output of part 3
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# check if using the default metadata data frame (the most recently saved)
if (
    metadata_file_name == None
    or metadata_file_name.lower() == "default"
    or metadata_file_name == ""
):

    # import target files in the metadata_directory
    metadata_files = listdirNHF(
        metadata_directory,
        target=default_metadata_file_target,
        exclude=default_metadata_file_exclude,
    )

    # get the default metadata file
    metadata_file_name = default_file_name(
        file_list=metadata_files,
        from_file_name=metadata_from_file_name,
        directory_path=metadata_directory,
        separator=metadata_default_separator,
        date_position=metadata_default_date_position,
        date_format=metadata_default_date_format,
        reverse=metadata_default_reverse,
    )

    print(f"using {metadata_file_name} as default metadata file")


# open the metadata file
metadata_df_i = pd.read_csv(os.path.join(metadata_directory, metadata_file_name))

# copy metadata_df
metadata_df = metadata_df_i.copy()

# # display the metadata dataframe
# metadata_df
# Out:
# using 20260805_ACID_metadata_part_4b.csv as default metadata file

# %% [markdown]
# #### Select test data set - NOTE: the metadata_df is updated into a metadata_df which does not contain the train data
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# Select only the train set and update metadata_df
metadata_df = metadata_df[metadata_df[is_train_column] == test_val]

# assert proper selection of train set
assert metadata_df.shape[0] > 0, "No rows in metadata_df belong to the train set."
assert all(
    metadata_df[is_train_column] == test_val
), "Not all rows in metadata_df belong to the train set."

# Display the metadata dataframe
metadata_df
# Out:
#                                  raw_file_name scene_name  \
# 0    H7_DENV2_MOI1_40h_fixed_stained_well6.nd2         A1
# 1    H7_DENV2_MOI1_40h_fixed_stained_well6.nd2         A2
# 2    H7_DENV2_MOI1_40h_fixed_stained_well6.nd2         A3
# 3    H7_DENV2_MOI1_40h_fixed_stained_well6.nd2         A4
# 4    H7_DENV2_MOI1_40h_fixed_stained_well6.nd2         A5
# ..                                         ...        ...
# 200  H7_DENV2_MOI1_40h_fixed_stained_well7.nd2         G1
# 201  H7_DENV2_MOI1_40h_fixed_stained_well7.nd2         G2
# 202  H7_DENV2_MOI1_40h_fixed_stained_well7.nd2         G3
# 203  H7_DENV2_MOI1_40h_fixed_stained_well7.nd2         G4
# 204  H7_DENV2_MOI1_40h_fixed_stained_well7.nd2         G7
#
#      processing_date_yymmdd  \
# 0                    260805
# 1                    260805
# 2                    260805
# 3                    260805
# 4                    260805
# ..                      ...
# 200                  260805
# 201                  260805
# 202                  260805
# 203                  260805
# 204                  260805
#
#                                      ome_tif_file_name  \
# 0    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A1...
# 1    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A2...
# 2    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A3...
# 3    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A4...
# 4    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A5...
# ..                                                 ...
# 200  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G1...
# 201  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G2...
# 202  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G3...
# 203  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G4...
# 204  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G7...
#
#                                               location  \
# 0    Center for Integrative Infectious Disease Rese...
# 1    Center for Integrative Infectious Disease Rese...
# 2    Center for Integrative Infectious Disease Rese...
# 3    Center for Integrative Infectious Disease Rese...
# 4    Center for Integrative Infectious Disease Rese...
# ..                                                 ...
# 200  Center for Integrative Infectious Disease Rese...
# 201  Center for Integrative Infectious Disease Rese...
# 202  Center for Integrative Infectious Disease Rese...
# 203  Center for Integrative Infectious Disease Rese...
# 204  Center for Integrative Infectious Disease Rese...
#
#                              microscope  \
# 0    Nikon Ti2 - CSU-W1 - spinning disc
# 1    Nikon Ti2 - CSU-W1 - spinning disc
# 2    Nikon Ti2 - CSU-W1 - spinning disc
# 3    Nikon Ti2 - CSU-W1 - spinning disc
# 4    Nikon Ti2 - CSU-W1 - spinning disc
# ..                                  ...
# 200  Nikon Ti2 - CSU-W1 - spinning disc
# 201  Nikon Ti2 - CSU-W1 - spinning disc
# 202  Nikon Ti2 - CSU-W1 - spinning disc
# 203  Nikon Ti2 - CSU-W1 - spinning disc
# 204  Nikon Ti2 - CSU-W1 - spinning disc
#
#                                   objective experiment condition_1  \
# 0    Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4          H7
# 1    Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4          H7
# 2    Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4          H7
# 3    Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4          H7
# 4    Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4          H7
# ..                                      ...        ...         ...
# 200  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.3          H7
# 201  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.3          H7
# 202  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.3          H7
# 203  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.3          H7
# 204  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.3          H7
#
#     infectious_organism  ... background_funct_gau_smooth  \
# 0                 DENV2  ...                         100
# 1                 DENV2  ...                         100
# 2                 DENV2  ...                         100
# 3                 DENV2  ...                         100
# 4                 DENV2  ...                         100
# ..                  ...  ...                         ...
# 200               DENV2  ...                         100
# 201               DENV2  ...                         100
# 202               DENV2  ...                         100
# 203               DENV2  ...                         100
# 204               DENV2  ...                         100
#
#     illumination_correction_date  \
# 0                         260805
# 1                         260805
# 2                         260805
# 3                         260805
# 4                         260805
# ..                           ...
# 200                       260805
# 201                       260805
# 202                       260805
# 203                       260805
# 204                       260805
#
#                      illumination_correction_file_name  \
# 0    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A1...
# 1    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A2...
# 2    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A3...
# 3    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A4...
# 4    H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A5...
# ..                                                 ...
# 200  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G1...
# 201  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G2...
# 202  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G3...
# 203  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G4...
# 204  H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G7...
#
#     illumination_correction_method illumination_correction_offset  \
# 0                         division                            400
# 1                         division                            400
# 2                         division                            400
# 3                         division                            400
# 4                         division                            400
# ..                             ...                            ...
# 200                       division                            400
# 201                       division                            400
# 202                       division                            400
# 203                       division                            400
# 204                       division                            400
#
#     illumination_correction_rescale_background  \
# 0                                          max
# 1                                          max
# 2                                          max
# 3                                          max
# 4                                          max
# ..                                         ...
# 200                                        max
# 201                                        max
# 202                                        max
# 203                                        max
# 204                                        max
#
#     illumination_correction_clip_output  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 200                               False
# 201                               False
# 202                               False
# 203                               False
# 204                               False
#
#     illumination_correction_min_clip_value  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ..                                     ...
# 200                                      0
# 201                                      0
# 202                                      0
# 203                                      0
# 204                                      0
#
#     illumination_correction_max_clip_value  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 200                                    NaN
# 201                                    NaN
# 202                                    NaN
# 203                                    NaN
# 204                                    NaN
#
#     illumination_correction_offset_background
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# ..                                        ...
# 200                                      True
# 201                                      True
# 202                                      True
# 203                                      True
# 204                                      True
#
# [205 rows x 50 columns]

# %%
# import target files in the background_directory
background_files = listdirNHF(
    background_directory,
    target=default_bg_funct_file_target,
    exclude=default_bg_funct_file_exclude,
)

if background_function_strategy == 1:

    # check if using the default background function name (the most recently saved)
    if (
        background_function_timestamp == None
        or background_function_timestamp.lower() == "default"
        or background_function_timestamp == ""
    ):
        bg_funct_file_name = default_file_name(
            file_list=background_files,
            from_file_name=background_from_file_name,
            directory_path=background_directory,
            separator=background_default_separator,
            date_position=background_default_date_position,
            date_format=background_default_date_format,
            reverse=background_default_reverse,
        )
        print(f"using {bg_funct_file_name} as default background function file")

    else:
        # select the background function file with the timestamp indicated in background_function_timestamp
        bg_funct_file_name = [
            f for f in background_files if background_function_timestamp in f
        ][0]

    # open the background function
    background_function = tifffile.imread(
        os.path.join(background_directory, bg_funct_file_name)
    )


elif background_function_strategy in [2, 3]:
    # check if using the default background function name (the most recently saved)
    if (
        background_function_timestamp == None
        or background_function_timestamp.lower() == "default"
        or background_function_timestamp == ""
    ):
        bg_funct_file_names = default_multifile_name(
            file_list=background_files,
            from_file_name=background_from_file_name,
            directory_path=background_directory,
            separator=background_default_separator,
            date_position=background_default_date_position,
            date_format=background_default_date_format,
            reverse=background_default_reverse,
        )

        print(f"using the following files as default background function files:")
        for f in bg_funct_file_names:
            print(f)
    else:
        # select the background function files with the timestamp indicated in background_function_timestamp
        bg_funct_file_names = [
            f for f in background_files if background_function_timestamp in f
        ]

    if background_function_strategy == 2:
        # get unique wells from the metadata dataframe
        unique_conditions = metadata_df[well_column_name].unique()
    elif background_function_strategy == 3:
        # get unique grid positions from the metadata dataframe
        unique_conditions = metadata_df[gridpos_column_name].unique()

    # assert that the number of background function files matches the number of unique wells
    assert len(bg_funct_file_names) == len(
        unique_conditions
    ), f"The number of background function files ({len(bg_funct_file_names)}) does not match the number of unique conditions ({len(unique_conditions)}). Please check the background function directory and the metadata dataframe."

    # map the background function files to the unique conditions (wells or grid positions depending on the strategy)
    bg_funct_file_dict = map_image_to_condition(
        condition_list=unique_conditions,
        image_file_names=bg_funct_file_names,
        assert_file_number=background_default_assert_file_number,
        number_of_files_expected=background_default_number_of_files_expected,
    )


else:
    raise ValueError(
        f"Invalid background function strategy: {background_function_strategy}. Please select either 1, 2 or 3."
    )
# Out:
# using 20260805_ACID_background.ome.tif as default background function file

# %% [markdown]
# #### Get the shape and the number of channels of the fields of view - NOTE: it is assumed that all fields of view in the dataset have the same shape and number of channels
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# get the shape of the individual fields of view, the number of channels and the shape of individual channels
fov_shape, num_channels, shape_of_channels = get_fov_ch_shape(
    metadata_df,
    fov_directory,
    fov_clm=fov_column_name,
    channel_axis=channel_axis,
    null_value=null_value,
)
# Out:
# field of view shape: (5, 1024, 1024)
# number of channels found: 5
# shape of channels: (1024, 1024)

# %% [markdown]
# ### MAIN LOOP

# %%
# initialize lists to collect processing metadata for updating - this will be used to update the metadata df
illum_correct_date_collection = []
illum_correct_file_name_collection = []
illum_correct_method_collection = []
illum_correct_offset_collection = []
illum_correct_rescale_collection = []
illum_correct_clipping_collection = []
illum_correct_clip_min_value_collection = []
illum_correct_clip_max_value_collection = []
illum_correct_offset_background_collection = []


# iterate through the rows of the metadata dataframe
for i in metadata_df.index:

    print("---------    ---------")

    # ---------
    # OPEN FIELD OF VIEW
    # ---------

    # get the field of view file
    field_of_view_file = metadata_df.loc[i, fov_column_name]

    print(f"working on {field_of_view_file}")

    # form full path to the field of view
    field_of_view_path = os.path.join(fov_directory, str(field_of_view_file))

    # try to open the field of view
    try:

        # open the field of view
        field_of_view = tifffile.imread(field_of_view_path)

    except:
        print(f"can't open {field_of_view_file}, skipping illumination correction")

        # add null_value to the collection lists
        illum_correct_date_collection.append(null_value)
        illum_correct_file_name_collection.append(null_value)
        illum_correct_method_collection.append(null_value)
        illum_correct_offset_collection.append(null_value)
        illum_correct_rescale_collection.append(null_value)
        illum_correct_clipping_collection.append(null_value)
        illum_correct_clip_min_value_collection.append(null_value)
        illum_correct_clip_max_value_collection.append(null_value)
        illum_correct_offset_background_collection.append(null_value)

        continue

    # ---------
    # UPDATE IMAGE METADATA
    # ---------
    # get field of view metadata
    field_of_view_metadata = extract_ometif_imagej_metadata(field_of_view_path)

    # update the image metadata data
    # first, update the processing date and the data type - NOTE: to stay consistent with how the
    # metadata is generated, first a dummy dictionary is created, which is converted as the orginal one,
    # before extracting the sole key
    processing_date_metadata_entry = list(
        imagej_compatible_metadata_dict({proc_img_meta_date_name: "dummy"})
    )[0]
    dtype_metadata_entry = list(
        imagej_compatible_metadata_dict({proc_img_meta_dtype_name: "dummy"})
    )[0]
    field_of_view_metadata[processing_date_metadata_entry] = (
        datetime.datetime.now().strftime(processing_date_format)
    )
    field_of_view_metadata[dtype_metadata_entry] = output_dtype

    # second, add information about the illumination correction process
    # form a dictionary storing the information to add to the metadata
    field_of_view_illcorr_metadata = {
        illum_corr_method_metadata_entry: method,
        illum_corr_offset_metadata_entry: offset,
        illum_corr_rescale_metadata_entry: rescale_background,
        illum_corr_clipping_metadata_entry: clip_corrected_image,
        illum_corr_clip_min_value_metadata_entry: min_clip_value,
        illum_corr_clip_max_value_metadata_entry: max_clip_value,
        illum_corr_offset_background_metadata_entry: offset_background,
    }

    # convert the dictionary so that entries are distinguishable from default ones
    field_of_view_illcorr_metadata = imagej_compatible_metadata_dict(
        field_of_view_illcorr_metadata
    )

    # update the metadata dictionary by adding the new information on illumination correction
    for k in field_of_view_illcorr_metadata:
        field_of_view_metadata[k] = field_of_view_illcorr_metadata[k]

    # ---------
    # STRATEGY 1
    # ---------
    if background_function_strategy == 1:

        # get the illumination corrected image
        illum_correct_field_of_view = correct_background(
            field_of_view,
            background=background_function,
            method=method,
            channel_axis=channel_axis,
            offset=offset,
            epsilon=epsilon,
            working_dtype=working_dtype,
            output_dtype=output_dtype,
            rescale_background=rescale_background,
            clip_corrected_image=clip_corrected_image,
            min_clip_value=min_clip_value,
            max_clip_value=max_clip_value,
            zero_kwargs=zero_kwargs,
            offset_background=offset_background,
            verbose=verbose,
        )

        # save the corrected image
        # form the saving name of the file
        save_file_name = f"{field_of_view_file.removesuffix(ome_suffix)}{save_file_name_separator}{fov_illumin_corrected_savingword}{ome_suffix}"

        tifffile_save_ometiff(
            os.path.join(output_directory, save_file_name),
            data=illum_correct_field_of_view,
            imagej=save_imagej_compatible,
            photometric=photometric,
            metadata=field_of_view_illcorr_metadata,
        )

        # update the metadata collection lists
        # add null_value to the collection lists
        illum_correct_date_collection.append(
            datetime.datetime.now().strftime(illum_correct_df_meta_date_format)
        )
        illum_correct_file_name_collection.append(save_file_name)
        illum_correct_method_collection.append(method)
        illum_correct_offset_collection.append(offset)
        illum_correct_rescale_collection.append(rescale_background)
        illum_correct_clipping_collection.append(clip_corrected_image)
        illum_correct_clip_min_value_collection.append(min_clip_value)
        illum_correct_clip_max_value_collection.append(max_clip_value)
        illum_correct_offset_background_collection.append(offset_background)

        # print progress update
        print("illumation correction done. File saved. Metadata updated")

    # ---------
    # STRATEGY 2
    # ---------
    elif background_function_strategy == 2:

        # get well
        fov_well = metadata_df.loc[i, well_column_name]

        # map the field of view with its background function
        well_background_function = bg_funct_file_dict[fov_well]

        # get the illumination corrected image
        illum_correct_field_of_view_well = correct_background(
            field_of_view,
            background=well_background_function,
            method=method,
            channel_axis=channel_axis,
            offset=offset,
            epsilon=epsilon,
            working_dtype=working_dtype,
            output_dtype=output_dtype,
            rescale_background=rescale_background,
            clip_corrected_image=clip_corrected_image,
            min_clip_value=min_clip_value,
            max_clip_value=max_clip_value,
            zero_kwargs=zero_kwargs,
            offset_background=offset_background,
            verbose=verbose,
        )

        # save the corrected image
        # form the saving name of the file
        save_file_name_well = f"{field_of_view_file.removesuffix(ome_suffix)}{save_file_name_separator}{fov_illumin_corrected_savingword}{ome_suffix}"

        tifffile_save_ometiff(
            os.path.join(output_directory, save_file_name_well),
            data=illum_correct_field_of_view_well,
            imagej=save_imagej_compatible,
            photometric=photometric,
            metadata=field_of_view_illcorr_metadata,
        )

        # update the metadata collection lists
        # add null_value to the collection lists
        illum_correct_date_collection.append(
            datetime.datetime.now().strftime(illum_correct_df_meta_date_format)
        )
        illum_correct_file_name_collection.append(save_file_name_well)
        illum_correct_method_collection.append(method)
        illum_correct_offset_collection.append(offset)
        illum_correct_rescale_collection.append(rescale_background)
        illum_correct_clipping_collection.append(clip_corrected_image)
        illum_correct_clip_min_value_collection.append(min_clip_value)
        illum_correct_clip_max_value_collection.append(max_clip_value)
        illum_correct_offset_background_collection.append(offset_background)

        # print progress update
        print("illumation correction done. File saved. Metadata updated")

    # ---------
    # STRATEGY 3
    # ---------
    elif background_function_strategy == 3:

        # get grid-position
        fov_scene = metadata_df.loc[i, gridpos_column_name]

        # map the field of view with its background function
        scene_background_function = bg_funct_file_dict[fov_scene]

        # get the illumination corrected image
        illum_correct_field_of_view_scene = correct_background(
            field_of_view,
            background=scene_background_function,
            method=method,
            channel_axis=channel_axis,
            offset=offset,
            epsilon=epsilon,
            working_dtype=working_dtype,
            output_dtype=output_dtype,
            rescale_background=rescale_background,
            clip_corrected_image=clip_corrected_image,
            min_clip_value=min_clip_value,
            max_clip_value=max_clip_value,
            zero_kwargs=zero_kwargs,
            offset_background=offset_background,
            verbose=verbose,
        )

        # save the corrected image
        # form the saving name of the file
        save_file_name_scene = f"{field_of_view_file.removesuffix(ome_suffix)}{save_file_name_separator}{fov_illumin_corrected_savingword}{ome_suffix}"

        tifffile_save_ometiff(
            os.path.join(output_directory, save_file_name_scene),
            data=illum_correct_field_of_view_scene,
            imagej=save_imagej_compatible,
            photometric=photometric,
            metadata=field_of_view_illcorr_metadata,
        )

        # update the metadata collection lists
        # add null_value to the collection lists
        illum_correct_date_collection.append(
            datetime.datetime.now().strftime(illum_correct_df_meta_date_format)
        )
        illum_correct_file_name_collection.append(save_file_name_scene)
        illum_correct_method_collection.append(method)
        illum_correct_offset_collection.append(offset)
        illum_correct_rescale_collection.append(rescale_background)
        illum_correct_clipping_collection.append(clip_corrected_image)
        illum_correct_clip_min_value_collection.append(min_clip_value)
        illum_correct_clip_max_value_collection.append(max_clip_value)
        illum_correct_offset_background_collection.append(offset_background)

        # print progress update
        print("illumation correction done. File saved. Metadata updated")

    else:
        raise ValueError("background_function_strategy must be 1, 2 or 3")

# print progress update
print("illumination correction finished")

# ---------
# UPDATE PROCESSING METADATA DATA FRAME
# ---------
metadata_df[illum_correct_df_date_clm_name] = illum_correct_date_collection
metadata_df[illum_correct_df_file_name_clm_name] = illum_correct_file_name_collection
metadata_df[illum_correct_df_method_clm_name] = illum_correct_method_collection
metadata_df[illum_correct_df_offset_clm_name] = illum_correct_offset_collection
metadata_df[illum_correct_df_rescale_clm_name] = illum_correct_rescale_collection
metadata_df[illum_correct_df_clipping_clm_name] = illum_correct_clipping_collection
metadata_df[illum_correct_df_clip_min_value_clm_name] = (
    illum_correct_clip_min_value_collection
)
metadata_df[illum_correct_df_clip_max_value_clm_name] = (
    illum_correct_clip_max_value_collection
)
metadata_df[illum_correct_df_offset_background_clm_name] = (
    illum_correct_offset_background_collection
)

# save the updated metadata dataframe as a csv file
metadata_df_name = f"{datetime.datetime.now().strftime(metadata_date_format)}{save_file_name_separator}{project_name}{save_file_name_separator}{metadata_savingword}{save_file_name_separator}{metadata_file_suffix}"
metadata_df.to_csv(
    os.path.join(metadata_directory, metadata_df_name), index=save_csv_index
)

# print progress update
print("metadata saved")
print("finished")
# Out:
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 428.0, image max: 902.0
# after correction image min: 39.496707916259766, image max: 511.6831359863281
# changing the data type of the output/corrected image
# final data type: float32, image min: 39.496707916259766, image max: 511.6831359863281
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 432.0, image max: 4164.0
# after correction image min: 44.951416015625, image max: 4294.62939453125
# changing the data type of the output/corrected image
# final data type: float32, image min: 44.951416015625, image max: 4294.62939453125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 432.0, image max: 12173.0
# after correction image min: 51.204349517822266, image max: 12437.974609375
# changing the data type of the output/corrected image
# final data type: float32, image min: 51.204349517822266, image max: 12437.974609375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 8020.0
# after correction image min: 36.330684661865234, image max: 8565.458984375
# changing the data type of the output/corrected image
# final data type: float32, image min: 36.330684661865234, image max: 8565.458984375
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2007.0, image max: 7432.0
# after correction image min: 1727.5706787109375, image max: 7398.45947265625
# changing the data type of the output/corrected image
# final data type: float32, image min: 1727.5706787109375, image max: 7398.45947265625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A2.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 446.0, image max: 3753.0
# after correction image min: 56.89299774169922, image max: 3536.8330078125
# changing the data type of the output/corrected image
# final data type: float32, image min: 56.89299774169922, image max: 3536.8330078125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 445.0, image max: 5454.0
# after correction image min: 56.67573928833008, image max: 5665.45068359375
# changing the data type of the output/corrected image
# final data type: float32, image min: 56.67573928833008, image max: 5665.45068359375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 445.0, image max: 16317.0
# after correction image min: 58.803043365478516, image max: 15971.83203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 58.803043365478516, image max: 15971.83203125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 8494.0
# after correction image min: 37.943546295166016, image max: 8273.8681640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 37.943546295166016, image max: 8273.8681640625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2020.0, image max: 6554.0
# after correction image min: 1630.653076171875, image max: 6516.6923828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1630.653076171875, image max: 6516.6923828125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 435.0, image max: 3628.0
# after correction image min: 49.01958465576172, image max: 3241.031494140625
# changing the data type of the output/corrected image
# final data type: float32, image min: 49.01958465576172, image max: 3241.031494140625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 6754.0
# after correction image min: 43.14626693725586, image max: 6415.32958984375
# changing the data type of the output/corrected image
# final data type: float32, image min: 43.14626693725586, image max: 6415.32958984375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 9816.0
# after correction image min: 42.78718185424805, image max: 9736.8203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 42.78718185424805, image max: 9736.8203125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 11689.0
# after correction image min: 36.497249603271484, image max: 13055.7890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 36.497249603271484, image max: 13055.7890625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2038.0, image max: 8611.0
# after correction image min: 1703.792236328125, image max: 8742.470703125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1703.792236328125, image max: 8742.470703125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A4.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 437.0, image max: 3805.0
# after correction image min: 48.22630310058594, image max: 4007.403564453125
# changing the data type of the output/corrected image
# final data type: float32, image min: 48.22630310058594, image max: 4007.403564453125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 438.0, image max: 4213.0
# after correction image min: 50.15049743652344, image max: 4219.140625
# changing the data type of the output/corrected image
# final data type: float32, image min: 50.15049743652344, image max: 4219.140625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 450.0, image max: 10591.0
# after correction image min: 57.10810852050781, image max: 12312.6015625
# changing the data type of the output/corrected image
# final data type: float32, image min: 57.10810852050781, image max: 12312.6015625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 422.0, image max: 1471.0
# after correction image min: 27.06773567199707, image max: 1086.145263671875
# changing the data type of the output/corrected image
# final data type: float32, image min: 27.06773567199707, image max: 1086.145263671875
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1906.0, image max: 6933.0
# after correction image min: 1573.3681640625, image max: 7229.126953125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1573.3681640625, image max: 7229.126953125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_A5.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 428.0, image max: 8459.0
# after correction image min: 39.46487808227539, image max: 8650.3408203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 39.46487808227539, image max: 8650.3408203125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 429.0, image max: 8737.0
# after correction image min: 41.863765716552734, image max: 9124.828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 41.863765716552734, image max: 9124.828125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 441.0, image max: 15403.0
# after correction image min: 60.8202018737793, image max: 15652.00390625
# changing the data type of the output/corrected image
# final data type: float32, image min: 60.8202018737793, image max: 15652.00390625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 423.0, image max: 65535.0
# after correction image min: 23.125568389892578, image max: 65825.8515625
# changing the data type of the output/corrected image
# final data type: float32, image min: 23.125568389892578, image max: 65825.8515625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2177.0, image max: 7003.0
# after correction image min: 1856.485595703125, image max: 7191.99462890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 1856.485595703125, image max: 7191.99462890625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_B7.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 423.0, image max: 3491.0
# after correction image min: 32.691795349121094, image max: 3143.68408203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 32.691795349121094, image max: 3143.68408203125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 438.0, image max: 7838.0
# after correction image min: 52.965030670166016, image max: 8146.89111328125
# changing the data type of the output/corrected image
# final data type: float32, image min: 52.965030670166016, image max: 8146.89111328125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 460.0, image max: 13383.0
# after correction image min: 86.35911560058594, image max: 19175.544921875
# changing the data type of the output/corrected image
# final data type: float32, image min: 86.35911560058594, image max: 19175.544921875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 417.0, image max: 3285.0
# after correction image min: 21.074527740478516, image max: 3047.90673828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 21.074527740478516, image max: 3047.90673828125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1910.0, image max: 10961.0
# after correction image min: 1647.9207763671875, image max: 10631.1552734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 1647.9207763671875, image max: 10631.1552734375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_B6.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 3410.0
# after correction image min: 44.66205596923828, image max: 3028.143310546875
# changing the data type of the output/corrected image
# final data type: float32, image min: 44.66205596923828, image max: 3028.143310546875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 439.0, image max: 1806.0
# after correction image min: 54.00098419189453, image max: 1573.9139404296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 54.00098419189453, image max: 1573.9139404296875
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 441.0, image max: 10749.0
# after correction image min: 66.16849517822266, image max: 13893.7373046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 66.16849517822266, image max: 13893.7373046875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 427.0, image max: 7883.0
# after correction image min: 33.64765930175781, image max: 7523.75390625
# changing the data type of the output/corrected image
# final data type: float32, image min: 33.64765930175781, image max: 7523.75390625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2125.0, image max: 9295.0
# after correction image min: 1765.470703125, image max: 9177.8837890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 1765.470703125, image max: 9177.8837890625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_B3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 433.0, image max: 2884.0
# after correction image min: 46.9162712097168, image max: 2671.684814453125
# changing the data type of the output/corrected image
# final data type: float32, image min: 46.9162712097168, image max: 2671.684814453125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 436.0, image max: 2500.0
# after correction image min: 45.83223342895508, image max: 2639.859619140625
# changing the data type of the output/corrected image
# final data type: float32, image min: 45.83223342895508, image max: 2639.859619140625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 442.0, image max: 15487.0
# after correction image min: 42.760292053222656, image max: 17158.927734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 42.760292053222656, image max: 17158.927734375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 420.0, image max: 1677.0
# after correction image min: 24.409029006958008, image max: 1431.997314453125
# changing the data type of the output/corrected image
# final data type: float32, image min: 24.409029006958008, image max: 1431.997314453125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1981.0, image max: 8720.0
# after correction image min: 1623.8695068359375, image max: 8368.4052734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 1623.8695068359375, image max: 8368.4052734375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_B2.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 3076.0
# after correction image min: 42.632957458496094, image max: 2878.75830078125
# changing the data type of the output/corrected image
# final data type: float32, image min: 42.632957458496094, image max: 2878.75830078125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 5770.0
# after correction image min: 48.25236129760742, image max: 5904.4716796875
# changing the data type of the output/corrected image
# final data type: float32, image min: 48.25236129760742, image max: 5904.4716796875
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 447.0, image max: 12209.0
# after correction image min: 62.96877670288086, image max: 13291.2568359375
# changing the data type of the output/corrected image
# final data type: float32, image min: 62.96877670288086, image max: 13291.2568359375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 427.0, image max: 4610.0
# after correction image min: 33.1758918762207, image max: 4820.9228515625
# changing the data type of the output/corrected image
# final data type: float32, image min: 33.1758918762207, image max: 4820.9228515625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2022.0, image max: 7511.0
# after correction image min: 1656.7850341796875, image max: 7428.79345703125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1656.7850341796875, image max: 7428.79345703125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_B1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 426.0, image max: 9280.0
# after correction image min: 36.87990951538086, image max: 9239.8671875
# changing the data type of the output/corrected image
# final data type: float32, image min: 36.87990951538086, image max: 9239.8671875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 3863.0
# after correction image min: 36.73047637939453, image max: 4585.9853515625
# changing the data type of the output/corrected image
# final data type: float32, image min: 36.73047637939453, image max: 4585.9853515625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 442.0, image max: 10213.0
# after correction image min: 54.87778091430664, image max: 12487.0419921875
# changing the data type of the output/corrected image
# final data type: float32, image min: 54.87778091430664, image max: 12487.0419921875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 419.0, image max: 3557.0
# after correction image min: 22.93659210205078, image max: 3271.960693359375
# changing the data type of the output/corrected image
# final data type: float32, image min: 22.93659210205078, image max: 3271.960693359375
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2057.0, image max: 8077.0
# after correction image min: 1695.429931640625, image max: 8183.5185546875
# changing the data type of the output/corrected image
# final data type: float32, image min: 1695.429931640625, image max: 8183.5185546875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_C1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 2819.0
# after correction image min: 48.05385208129883, image max: 2489.773193359375
# changing the data type of the output/corrected image
# final data type: float32, image min: 48.05385208129883, image max: 2489.773193359375
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 3761.0
# after correction image min: 45.5452880859375, image max: 4065.0283203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 45.5452880859375, image max: 4065.0283203125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 419.0, image max: 21823.0
# after correction image min: 33.69226837158203, image max: 25423.474609375
# changing the data type of the output/corrected image
# final data type: float32, image min: 33.69226837158203, image max: 25423.474609375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 424.0, image max: 4527.0
# after correction image min: 29.340682983398438, image max: 4820.27294921875
# changing the data type of the output/corrected image
# final data type: float32, image min: 29.340682983398438, image max: 4820.27294921875
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1900.0, image max: 8184.0
# after correction image min: 1601.4173583984375, image max: 8098.74658203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1601.4173583984375, image max: 8098.74658203125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_C5.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 444.0, image max: 3671.0
# after correction image min: 63.436031341552734, image max: 3308.333984375
# changing the data type of the output/corrected image
# final data type: float32, image min: 63.436031341552734, image max: 3308.333984375
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 423.0, image max: 904.0
# after correction image min: 32.4148063659668, image max: 698.2197875976562
# changing the data type of the output/corrected image
# final data type: float32, image min: 32.4148063659668, image max: 698.2197875976562
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 461.0, image max: 9788.0
# after correction image min: 92.96458435058594, image max: 12201.1884765625
# changing the data type of the output/corrected image
# final data type: float32, image min: 92.96458435058594, image max: 12201.1884765625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 3216.0
# after correction image min: 30.241811752319336, image max: 2853.16064453125
# changing the data type of the output/corrected image
# final data type: float32, image min: 30.241811752319336, image max: 2853.16064453125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2017.0, image max: 10598.0
# after correction image min: 1713.2467041015625, image max: 10952.9677734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 1713.2467041015625, image max: 10952.9677734375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_C7.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 444.0, image max: 6755.0
# after correction image min: 62.35503387451172, image max: 6656.8056640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 62.35503387451172, image max: 6656.8056640625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 423.0, image max: 3302.0
# after correction image min: 32.79768753051758, image max: 3095.55126953125
# changing the data type of the output/corrected image
# final data type: float32, image min: 32.79768753051758, image max: 3095.55126953125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 459.0, image max: 10028.0
# after correction image min: 59.95005798339844, image max: 11120.0361328125
# changing the data type of the output/corrected image
# final data type: float32, image min: 59.95005798339844, image max: 11120.0361328125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 7936.0
# after correction image min: 42.11028289794922, image max: 7670.57958984375
# changing the data type of the output/corrected image
# final data type: float32, image min: 42.11028289794922, image max: 7670.57958984375
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2170.0, image max: 7394.0
# after correction image min: 1882.325927734375, image max: 7357.8857421875
# changing the data type of the output/corrected image
# final data type: float32, image min: 1882.325927734375, image max: 7357.8857421875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_D7.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 441.0, image max: 4201.0
# after correction image min: 57.933746337890625, image max: 3881.947998046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 57.933746337890625, image max: 3881.947998046875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 436.0, image max: 1580.0
# after correction image min: 51.052799224853516, image max: 1306.6534423828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 51.052799224853516, image max: 1306.6534423828125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 453.0, image max: 13592.0
# after correction image min: 81.1952896118164, image max: 13213.25
# changing the data type of the output/corrected image
# final data type: float32, image min: 81.1952896118164, image max: 13213.25
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 1146.0
# after correction image min: 27.427452087402344, image max: 804.419921875
# changing the data type of the output/corrected image
# final data type: float32, image min: 27.427452087402344, image max: 804.419921875
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1882.0, image max: 13340.0
# after correction image min: 1577.23486328125, image max: 13624.146484375
# changing the data type of the output/corrected image
# final data type: float32, image min: 1577.23486328125, image max: 13624.146484375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_D5.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 442.0, image max: 3675.0
# after correction image min: 59.503170013427734, image max: 3332.589111328125
# changing the data type of the output/corrected image
# final data type: float32, image min: 59.503170013427734, image max: 3332.589111328125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 418.0, image max: 975.0
# after correction image min: 24.941740036010742, image max: 634.2836303710938
# changing the data type of the output/corrected image
# final data type: float32, image min: 24.941740036010742, image max: 634.2836303710938
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 465.0, image max: 15057.0
# after correction image min: 111.33157348632812, image max: 17353.91796875
# changing the data type of the output/corrected image
# final data type: float32, image min: 111.33157348632812, image max: 17353.91796875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 424.0, image max: 2768.0
# after correction image min: 29.0311336517334, image max: 2393.714599609375
# changing the data type of the output/corrected image
# final data type: float32, image min: 29.0311336517334, image max: 2393.714599609375
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 2076.0, image max: 8694.0
# after correction image min: 1761.0491943359375, image max: 8752.0625
# changing the data type of the output/corrected image
# final data type: float32, image min: 1761.0491943359375, image max: 8752.0625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_D2.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 436.0, image max: 2024.0
# after correction image min: 46.097076416015625, image max: 1635.9012451171875
# changing the data type of the output/corrected image
# final data type: float32, image min: 46.097076416015625, image max: 1635.9012451171875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 430.0, image max: 1303.0
# after correction image min: 42.0104866027832, image max: 1239.0667724609375
# changing the data type of the output/corrected image
# final data type: float32, image min: 42.0104866027832, image max: 1239.0667724609375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 442.0, image max: 11472.0
# after correction image min: 52.65334701538086, image max: 11793.369140625
# changing the data type of the output/corrected image
# final data type: float32, image min: 52.65334701538086, image max: 11793.369140625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 424.0, image max: 5002.0
# after correction image min: 29.458480834960938, image max: 4687.6025390625
# changing the data type of the output/corrected image
# final data type: float32, image min: 29.458480834960938, image max: 4687.6025390625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1929.0, image max: 8384.0
# after correction image min: 1606.58349609375, image max: 8535.916015625
# changing the data type of the output/corrected image
# final data type: float32, image min: 1606.58349609375, image max: 8535.916015625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well6_A07p4_D1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 432.0, image max: 3513.0
# after correction image min: 43.27314758300781, image max: 3178.057373046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 43.27314758300781, image max: 3178.057373046875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 1616.0
# after correction image min: 42.501766204833984, image max: 1341.00048828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 42.501766204833984, image max: 1341.00048828125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 453.0, image max: 11443.0
# after correction image min: 54.0894775390625, image max: 12088.3515625
# changing the data type of the output/corrected image
# final data type: float32, image min: 54.0894775390625, image max: 12088.3515625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 3270.0
# after correction image min: 40.969268798828125, image max: 2934.8798828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 40.969268798828125, image max: 2934.8798828125
# --- ch 4
# offsetting the background
# ...
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 471.0, image max: 15125.0
# after correction image min: 108.48358917236328, image max: 18180.005859375
# changing the data type of the output/corrected image
# final data type: float32, image min: 108.48358917236328, image max: 18180.005859375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 430.0, image max: 4283.0
# after correction image min: 33.014808654785156, image max: 3925.2373046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 33.014808654785156, image max: 3925.2373046875
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1882.0, image max: 5710.0
# after correction image min: 1508.9239501953125, image max: 5545.22509765625
# changing the data type of the output/corrected image
# final data type: float32, image min: 1508.9239501953125, image max: 5545.22509765625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 426.0, image max: 3784.0
# after correction image min: 37.403507232666016, image max: 3407.048828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 37.403507232666016, image max: 3407.048828125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 440.0, image max: 5774.0
# after correction image min: 50.77390670776367, image max: 5963.5283203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 50.77390670776367, image max: 5963.5283203125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 456.0, image max: 16530.0
# after correction image min: 60.946964263916016, image max: 20952.025390625
# changing the data type of the output/corrected image
# final data type: float32, image min: 60.946964263916016, image max: 20952.025390625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 12149.0
# after correction image min: 37.9342155456543, image max: 14429.904296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 37.9342155456543, image max: 14429.904296875
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1697.0, image max: 8342.0
# after correction image min: 1338.9510498046875, image max: 7998.29736328125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1338.9510498046875, image max: 7998.29736328125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G2.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 3541.0
# after correction image min: 33.704647064208984, image max: 3164.546875
# changing the data type of the output/corrected image
# final data type: float32, image min: 33.704647064208984, image max: 3164.546875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 438.0, image max: 5882.0
# after correction image min: 52.87913513183594, image max: 5976.25830078125
# changing the data type of the output/corrected image
# final data type: float32, image min: 52.87913513183594, image max: 5976.25830078125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 445.0, image max: 15394.0
# after correction image min: 75.66697692871094, image max: 17511.0234375
# changing the data type of the output/corrected image
# final data type: float32, image min: 75.66697692871094, image max: 17511.0234375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 7028.0
# after correction image min: 30.513526916503906, image max: 6737.9453125
# changing the data type of the output/corrected image
# final data type: float32, image min: 30.513526916503906, image max: 6737.9453125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1745.0, image max: 6566.0
# after correction image min: 1400.255126953125, image max: 6499.3623046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 1400.255126953125, image max: 6499.3623046875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 427.0, image max: 4064.0
# after correction image min: 37.853145599365234, image max: 3726.686279296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 37.853145599365234, image max: 3726.686279296875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 436.0, image max: 2731.0
# after correction image min: 52.81053924560547, image max: 2983.32177734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 52.81053924560547, image max: 2983.32177734375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 457.0, image max: 14925.0
# after correction image min: 75.81396484375, image max: 17353.578125
# changing the data type of the output/corrected image
# final data type: float32, image min: 75.81396484375, image max: 17353.578125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 427.0, image max: 1455.0
# after correction image min: 33.15434646606445, image max: 1068.5972900390625
# changing the data type of the output/corrected image
# final data type: float32, image min: 33.15434646606445, image max: 1068.5972900390625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1770.0, image max: 8316.0
# after correction image min: 1382.021728515625, image max: 8038.92578125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1382.021728515625, image max: 8038.92578125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G4.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 438.0, image max: 5598.0
# after correction image min: 48.194400787353516, image max: 5206.814453125
# changing the data type of the output/corrected image
# final data type: float32, image min: 48.194400787353516, image max: 5206.814453125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 435.0, image max: 3478.0
# after correction image min: 50.59716033935547, image max: 3477.27392578125
# changing the data type of the output/corrected image
# final data type: float32, image min: 50.59716033935547, image max: 3477.27392578125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 460.0, image max: 12343.0
# after correction image min: 81.13695526123047, image max: 14689.181640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 81.13695526123047, image max: 14689.181640625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 432.0, image max: 792.0
# after correction image min: 38.730525970458984, image max: 409.0894470214844
# changing the data type of the output/corrected image
# final data type: float32, image min: 38.730525970458984, image max: 409.0894470214844
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1825.0, image max: 8300.0
# after correction image min: 1483.9375, image max: 8063.96533203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1483.9375, image max: 8063.96533203125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well7_A07p3_G7.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 109.3516845703125, background max: 160.1163330078125
# after rescaling background min: 0.6829514503479004, background max: 1.0
# correct background with division method
# before correction image min: 432.0, image max: 3118.0
# after correction image min: 40.917667388916016, image max: 2756.936767578125
# changing the data type of the output/corrected image
# final data type: float32, image min: 40.917667388916016, image max: 2756.936767578125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 137.40484619140625, background max: 202.2491455078125
# after rescaling background min: 0.6793840527534485, background max: 1.0
# correct background with division method
# before correction image min: 449.0, image max: 5840.0
# after correction image min: 56.83792495727539, image max: 6680.654296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 56.83792495727539, image max: 6680.654296875
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 360.65301513671875, background max: 644.9405517578125
# after rescaling background min: 0.5592035055160522, background max: 1.0
# correct background with division method
# before correction image min: 452.0, image max: 21196.0
# after correction image min: 55.72439193725586, image max: 25172.884765625
# changing the data type of the output/corrected image
# final data type: float32, image min: 55.72439193725586, image max: 25172.884765625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 93.1485595703125, background max: 116.19500732421875
# after rescaling background min: 0.8016571402549744, background max: 1.0
# correct background with division method
# before correction image min: 423.0, image max: 2164.0
# after correction image min: 25.844013214111328, image max: 1819.3260498046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 25.844013214111328, image max: 1819.3260498046875
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2988.632080078125, background max: 3391.28564453125
# after rescaling background min: 0.8812681436538696, background max: 1.0
# correct background with division method
# before correction image min: 1828.0, image max: 6657.0
# after correction image min: 1447.1607666015625, image max: 6299.76953125
# changing the data type of the output/corrected image
# final data type: float32, image min: 1447.1607666015625, image max: 6299.76953125
# illumation correction done. File saved. Metadata updated
# illumination correction finished
# metadata saved
# finished

# %% [markdown]
# ### Display the result

# %%
import random

random.seed(42)
# randomly select a field of view before and after correction
random_field_of_view_idx = random.choice(list(metadata_df.index))
random_field_of_view_name = metadata_df.loc[random_field_of_view_idx, fov_column_name]
random_field_of_view_corrected_name = metadata_df.loc[
    random_field_of_view_idx, illum_correct_df_file_name_clm_name
]
print(f"""
displaying the result for:
{random_field_of_view_name}
{random_field_of_view_corrected_name}
""")
random_field_of_view = tifffile.imread(
    os.path.join(fov_directory, random_field_of_view_name)
)
random_field_of_view_corrected = tifffile.imread(
    os.path.join(output_directory, random_field_of_view_corrected_name)
)


fig, axes = plt.subplots(num_channels, 4, figsize=(12, 3 * num_channels))

plot_image_channels_and_diagonals(
    random_field_of_view,
    random_field_of_view_corrected,
    channel_axis=channel_axis,
    axes=axes,
    title_1="Original",
    title_2="Corrected",
    title_3="Main Diagonal",
    title_4="Anti Diagonal",
    x_axis="Pixel index",
    y_axis="Intensity",
    normalize=False,
)


# save graph
if save_graphs:
    graph_saving_name = f"{datetime.datetime.now().strftime(graph_date_format)}{save_file_name_separator}{project_name}{save_file_name_separator}{graph_savingword}{graph_suffix}"
    fig.savefig(os.path.join(graph_saving_directory, graph_saving_name))
    print(f"graph saved as {graph_saving_name} in {graph_saving_directory}")
else:
    print("graph not saved, set save_graphs to True to save the graph")
# Out:
# displaying the result for:
# H7_DENV2_MOI1_40h_fixed_stained_well4_A07p3_F3.ome.tif
# H7_DENV2_MOI1_40h_fixed_stained_well4_A07p3_F3_bg.ome.tif
#
# --- channel 0
# before correction. min value: 436. max value: 3995
# after correction. min value: 50.861148834228516. max value: 3617.0830078125
# --- channel 1
# before correction. min value: 439. max value: 3048
# after correction. min value: 54.58212661743164. max value: 2917.65625
# --- channel 2
# before correction. min value: 468. max value: 20325
# after correction. min value: 97.20280456542969. max value: 23722.38671875
# --- channel 3
# before correction. min value: 429. max value: 1045
# after correction. min value: 32.234867095947266. max value: 659.1968383789062
# --- channel 4
# before correction. min value: 1771. max value: 9316
# after correction. min value: 1479.1160888671875. max value: 9419.16796875
# graph saved as 20260805_ACID_illumination_correction.png in /home/christine/Sandbox/ACID/data/raw/proc/illumination_correction/test

# %% [markdown]
# ### Save hyperparameters
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# # collect hyperparameters in a dictionary

hyperparameter_dict = {
    "background_function_strategy": background_function_strategy,
    "background_directory": background_directory,
    "metadata_directory": metadata_directory,
    "fov_directory": fov_directory,
    "output_directory": output_directory,
    "metadata_file_name": metadata_file_name,
    "background_function_timestamp": background_function_timestamp,
    "save_graphs": save_graphs,
    "graph_saving_directory": graph_saving_directory,
    "is_train_column": is_train_column,
    "test_val": test_val,
    "default_bg_funct_file_target": default_bg_funct_file_target,
    "default_bg_funct_file_exclude": default_bg_funct_file_exclude,
    "background_from_file_name": background_from_file_name,
    "background_default_separator": background_default_separator,
    "background_default_date_position": background_default_date_position,
    "background_default_date_format": background_default_date_format,
    "background_default_reverse": background_default_reverse,
    "background_default_assert_file_number": background_default_assert_file_number,
    "background_default_number_of_files_expected": background_default_number_of_files_expected,
    "default_metadata_file_target": default_metadata_file_target,
    "default_metadata_file_exclude": default_metadata_file_exclude,
    "metadata_from_file_name": metadata_from_file_name,
    "metadata_default_separator": metadata_default_separator,
    "metadata_default_date_position": metadata_default_date_position,
    "metadata_default_date_format": metadata_default_date_format,
    "metadata_default_reverse": metadata_default_reverse,
    "channel_axis": channel_axis,
    "method": method,
    "offset": offset,
    "epsilon": epsilon,
    "output_dtype": output_dtype,
    "working_dtype": working_dtype,
    "rescale_background": rescale_background,
    "clip_corrected_image": clip_corrected_image,
    "min_clip_value": min_clip_value,
    "max_clip_value": max_clip_value,
    "offset_background": offset_background,
    "zero_kwargs": zero_kwargs,
    "verbose": verbose,
    "fov_column_name": fov_column_name,
    "well_column_name": well_column_name,
    "gridpos_column_name": gridpos_column_name,
    "null_value": null_value,
    "proc_img_meta_date_name": proc_img_meta_date_name,
    "processing_date_format": processing_date_format,
    "proc_img_meta_dtype_name": proc_img_meta_dtype_name,
    "illum_corr_method_metadata_entry": illum_corr_method_metadata_entry,
    "illum_corr_offset_metadata_entry": illum_corr_offset_metadata_entry,
    "illum_corr_rescale_metadata_entry": illum_corr_rescale_metadata_entry,
    "illum_corr_clipping_metadata_entry": illum_corr_clipping_metadata_entry,
    "illum_corr_clip_min_value_metadata_entry": illum_corr_clip_min_value_metadata_entry,
    "illum_corr_clip_max_value_metadata_entry": illum_corr_clip_max_value_metadata_entry,
    "illum_corr_offset_background_metadata_entry": illum_corr_offset_background_metadata_entry,
    "photometric": photometric,
    "save_imagej_compatible": save_imagej_compatible,
    "column_name_separator": column_name_separator,
    "ch_name_separator": ch_name_separator,
    "illum_correct_df_date_clm_name": illum_correct_df_date_clm_name,
    "illum_correct_df_meta_date_format": illum_correct_df_meta_date_format,
    "illum_correct_df_file_name_clm_name": illum_correct_df_file_name_clm_name,
    "illum_correct_df_method_clm_name": illum_correct_df_method_clm_name,
    "illum_correct_df_offset_clm_name": illum_correct_df_offset_clm_name,
    "illum_correct_df_rescale_clm_name": illum_correct_df_rescale_clm_name,
    "illum_correct_df_clipping_clm_name": illum_correct_df_clipping_clm_name,
    "illum_correct_df_clip_min_value_clm_name": illum_correct_df_clip_min_value_clm_name,
    "illum_correct_df_clip_max_value_clm_name": illum_correct_df_clip_max_value_clm_name,
    "illum_correct_df_offset_background_clm_name": illum_correct_df_offset_background_clm_name,
    "save_file_name_separator": save_file_name_separator,
    "project_name": project_name,
    "save_csv_index": save_csv_index,
    "fov_illumin_corrected_savingword": fov_illumin_corrected_savingword,
    "ome_suffix": ome_suffix,
    "metadata_savingword": metadata_savingword,
    "metadata_file_suffix": metadata_file_suffix,
    "metadata_date_format": metadata_date_format,
    "hyperparameters_date_format": hyperparameters_date_format,
    "hyperparameters_savingword": hyperparameters_savingword,
    "hyperparameters_file_suffix": hyperparameters_file_suffix,
    "graph_date_format": graph_date_format,
    "graph_suffix": graph_suffix,
    "graph_savingword": graph_savingword,
    "secondary_output_directory": secondary_output_directory,
    "exist_ok": exist_ok,
}


# transform the hyperparameter_dict in a pandas series
hyperparameter_series = pd.Series(hyperparameter_dict)

# save hyperparamters
hyperparameter_saving_name = f"{datetime.datetime.now().strftime(hyperparameters_date_format)}{save_file_name_separator}{project_name}{save_file_name_separator}{hyperparameters_savingword}{save_file_name_separator}{hyperparameters_file_suffix}"
hyperparameter_series.to_csv(
    os.path.join(secondary_output_directory, hyperparameter_saving_name),
    index=save_csv_index,
)
