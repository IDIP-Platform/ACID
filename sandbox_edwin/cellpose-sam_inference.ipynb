# %%
import numpy as np
import matplotlib.pyplot as plt
from cellpose import models, io
from cellpose.io import imread

# %%
io.logger_setup()

model = models.CellposeModel(gpu=True)

# list of files
# PUT PATH TO YOUR FILES HERE!

path_images = "data_example/"
files = ['H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_A1.ome.tif']

imgs = [imread(path_images+f) for f in files]
nimg = len(imgs)

masks, flows, styles = model.eval(imgs)

# %%
masks[0].shape
