# %% [markdown]
# ### **ACID - PART 4b - Test correct background illumination**
#
# # --- --- ---
#
# ### This notebook tests the use of a saved background function generated on part 4a notebook using a train set of data to correct for illumination artifacts on unseen data (test data).
#
# # --- --- ---
#
# **Author:** Alessandro Ulivi (alessandro.ulivi.89@gmail.com)
#
# **Last update (yyyy/mm/dd):** 2026/03/20

# %% [markdown]
# ## **---------------------------**

# %% [markdown]
# ### Import required modules
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# Import required modules
import datetime
import os
from pathlib import Path
import numpy as np
import pandas as pd
import tifffile
import matplotlib.pyplot as plt
from utils.listdirNHF import listdirNHF
from utils.get_defaults import default_file_name, default_multifile_name
from utils.fov_axis_utils import get_fov_ch_shape
from utils.save_image import tifffile_save_ometiff
from utils.miscellaneous_utils import map_image_to_condition
from image_processing.extract_metadata import extract_ometif_imagej_metadata
from image_processing.make_imagej_metadata import imagej_compatible_metadata_dict
from image_processing.correct_background import correct_background
from image_visualization.display_illumination_correction import plot_image_channels_and_diagonals

# %% [markdown]
# ### Specify the paths to input and output data directories - specify hyperparameters
#
# Run the following cell.
#
# Some parts of the following cell should be modified. The parts NOT to modify are under the line ""--- --- --- DON'T MODIFY THE FOLLOWING LINES --- --- ---"

# %%
# background function computation strategy - this is the strategy used in part4a notebook for
# calculating the background function. Possible options are: 1,2,3.
# 1 - calculate a  background function per channel using all the fields of view in the dataset which are not flagged
# 2 - calculate a background function per each channel and well using the fields of view in the train set which are not
# flagged and belong to the well
# 3 - calculate a background function per each channel and grid position using the fields of view in the train set which are
# not flagged and belong to the same position (aka grid position) across different wells
background_function_strategy = 1

# indicate the path to the directory storing the background function images
background_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\data\proc\background"

# indicate the path to the directory storing the metadata file - NOTE: this is expected to be the metadata_df saved
# from either part4a or part3 notebook
metadata_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\data\proc\proc_metadata"
# metadata_directory = r"C:\Users\aless\OneDrive\Desktop\Ale\lab\CIID_IDIP\projects\ACID\data\proc\proc_metadata"

# indicate the path to the directory storing the fields of view
fov_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\data\proc\fov"
# fov_directory = r"C:\Users\aless\OneDrive\Desktop\Ale\lab\CIID_IDIP\projects\ACID\data\proc\fov"

# # indicate the path to the directory where outputs will be saved
# NOTE: it the directory does not exist, the pipeline will try to create it
output_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\data\proc\fov_proc"
# output_directory = r"C:\Users\aless\OneDrive\Desktop\Ale\lab\CIID_IDIP\projects\ACID\data\proc\fov_proc"


# name of the metadata file - NOTE: this is expected to be the metadata_df saved
# from part3 notebook
# the following options are possible:
# 1) write the full name (extension included) of the csv file
# 2) write "default" or any other version with a uppercase letter (e.g. "Default")
# 3) leave an empty string: ""
# 4) write None (NOTE that this is not a string, there are no "", aka it is not "None")
# Options 2,3 and 4 will lead to the same behavior: the most recently saved csv file will be used.
# By default, the timestamp of the last file modification is used. As an alternative it is possible to use the
# date saved in the name (change below parameter metadata_from_file_name to True -
# see utils.get_defaults.default_file_name documentation).
metadata_file_name = "20251211_ACID_metadata_part_2.csv"

# the timestamp (aka the date) present in the file name of the background function image. This is used for selecting the
# background function image to use for the illumination correction in part4b notebook.

# the following options are possible:
# 0) ONLY POSSIBLE FOR STRATEGY 1 - write the full name (extension included) of the background function image file.
# In this case, the file will be selected based on the name and not on the timestamp.
# 1) write the timestamp (aka the date) as a string (e.g. "20251126"). NOTE: the string must match the exact format
# used for in the file name. For example, if the file name is "251126_plate_layout.csv",
# the timestamp string should be "251126" and not "20251126".
# ALSO NOTE: that the if strategy is 1, only a single file with the timestamp in the name is expected in the
# background function directory. If strategy 2 or 3 are selected, a number of files
# corresponding to the number of wells or grid positions, respectively, are expected.
# 2) write "default" or any other version with a uppercase letter (e.g. "Default")
# 3) leave an empty string: ""
# 4) write None (NOTE that this is not a string, there are no "", aka it is not "None")
# Options 2,3 and 4 will lead to the same behavior: the most recently saved ome.tif files will be used.
# By default, the timestamp of the last file modification is used. As an alternative it is possible to use the
# date saved in the name (change below parameter metadata_from_file_name to True -
# see utils.get_defaults.default_file_name documentation).
# TECHNICAL NOTE: the use of the timestamp is not strictly necessary. In particular: any string which allows to
# uniquely identify the file(s) to use for the background function can be used.
background_function_timestamp = "default"

# indicate whether to save the graphs generated in this notebook
save_graphs = True

# graph saving directory - this is the directory where the graphs generated in this notebook will be saved
graph_saving_directory = r"Z:\AlessandroUlivi_Data\projects\ACID\develop\260319_illumination_correction\test"




# ""--- --- --- DON'T MODIFY THE FOLLOWING LINES --- --- ---"
# # --- parameters to select the train set ---
# indicate the name of the column indicating whether the row belongs to train or test set
is_train_column="is_train"

# indicate the value signalling that a row (aka a field of view) belongs to the train set
test_val=0


# # --- parameters used for importing the default background function ---
# Indicate the part of the file name to use to select files into background_directory to be used for selecting the default
# file
default_bg_funct_file_target = ".ome.tif" # files with this string in their name will be selected for the default file selection - if None, all files will be selected
default_bg_funct_file_exclude = None # files with this string in their name will be excluded from the default file selection - if None, no files will be excluded

# Indicate whether to extract the date information from the file name when selecting the default file
# If False, the date will be extracted from the file's last modified timestamp, if True, from the file name.
# If from_file_name is True, the parameters *_default_separator and *_default_date_position
# should be used to indicate, respectively the separator to use for splitting the file name into tokens and
# the position of the token containing the date information. In addition, the date format used to include the date in the file name
# should be indicated using the parameters *_default_date_format.
# For example, if background_from_file_name is True, and the file name is "251126_plate_layout.csv",
# "_" is used as separator, 0 as date position, and '%Y%m%d' as date format.
# Ref to utils.get_defaults.default_file_name for more details.
background_from_file_name = False # if False, the date will be extracted from the file's last modified timestamp, if True, from the file name.

# separator - used to split the file name and extract the information token with the date
# if background_from_file_name is True
background_default_separator = '_'

# date position - the position of the date information token after splitting the file name using file_name_separator (above)
# used if background_from_file_name is True
background_default_date_position = 0

# date format - the format used for including the date in the file name to be opened by default
# used if background_from_file_name is True
background_default_date_format='%Y%m%d'

# reverse - if True, the file with the most recent date will be returned by default - if False, the opposite
background_default_reverse = True

# assert file number - this indicates whether to assert that the number of files matching the
# default file selection criteria is exactly one.
# If True, an assertion error will be raised if the number of files matching the criteria
# is not exactly one. If False, no assertion will be made and the function will return all the files
# matching the default file selection criteria. It is recommended to set this parameter to True when
# background_function_strategy is 1, since in this case only one background function file is expected to
# be used for the illumination correction. When background_function_strategy is 2 or 3, it is recommended
# to set this
background_default_assert_file_number=True
background_default_number_of_files_expected=1


# # --- parameters used for importing the default metadata dataframe ---
# Indicate the part of the file name to use to select files into metadata_directory to be used for selecting the default
# file
default_metadata_file_target = ".csv" # files with this string in their name will be selected for the default file selection - if None, all files will be selected
default_metadata_file_exclude = None # files with this string in their name will be excluded from the default file selection - if None, no files will be excluded

# Indicate whether to extract the date information from the file name when selecting the default file
# If False, the date will be extracted from the file's last modified timestamp, if True, from the file name.
# If from_file_name is True, the parameters *_default_separator and *_default_date_position
# should be used to indicate, respectively the separator to use for splitting the file name into tokens and
# the position of the token containing the date information. In addition, the date format used to include the date in the file name
# should be indicated using the parameters *_default_date_format.
# For example, if metadata_from_file_name is True, and the file name is "251126_plate_layout.csv",
# "_" is used as separator, 0 as date position, and '%Y%m%d' as date format.
# Ref to utils.get_defaults.default_file_name for more details.
metadata_from_file_name = False

# separator - used to split the file name and extract the information token with the date
# if metadata_from_file_name is True
metadata_default_separator = '_'

# date position - the position of the date information token after splitting the file name using file_name_separator (above)
# used if metadata_from_file_name is True
metadata_default_date_position = 0

# date format - the format used for including the date in the file name to be opened by default
# used if metadata_from_file_name is True
metadata_default_date_format='%Y%m%d'

# reverse - if True, the file with the most recent date will be returned by default - if False, the opposite
metadata_default_reverse = True


# --- parameters for background illumination correction ---
# channel axis to be passed to background calculating functions in order to calculate background functions per channel
# this is the axis along which the channels are organized in the field of view arrays.
# For example, if the field of view arrays have shape (channels, height, width), the channel axis is 0.
channel_axis = 0

# # data type to use for computing the illumination correction - the illumination correction is computed by
# # dividing the original field of view by a normalized background function. The data type to use for the field of view
# # when computing the division can be set here. It is recommended to use a floating point data type
# # (e.g. np.float32) to avoid issues with integer division and to preserve the precision of the background function.
# correction_operation_dtype_fov = np.float64

# # data type to use for computing the illumination correction - the illumination correction is computed by
# # dividing the original field of view by a normalized background function. The data type to use for the background
# # function when normalizing the histogram values and when computing the division can be set here. It is recommended
# # to use a floating point data type (e.g. np.float32) to avoid issues with integer division and to preserve the
# # precision of the background function.
# correction_operation_dtype_bg = np.float64

# the method used for illumination correction - this can be either "subtraction" or "division"
# method="subtraction"
method="division"

# the offset to subtract from the image before correcting for the illumination
offset=400

# the small constant to add to the background in oder to avoid zero numbers in the background function, which
# would lead to mathematical instability (e.g. division by zero)
epsilon=1e-8

# the data type of the image corrected for illumination
output_dtype=np.float32
# output_dtype=np.int16

# the data type to use for the mathematical operations (subtraction and division) during illumination correction.
# NOTE: the same data type is used for both the image to correct and the background function
working_dtype = np.float32
# working_dtype = np.int16

# whether or not to rescale the background function before carrying out illumination correction.
# Three options are available:
# 1) None -> no rescaling is done.
# 2) "max" -> the background function is divided by the max value. The resulting, normalized background function has 1 as max value.
# 3) "minmax" -> the background function is min-max normalized (background - min) / (max - min + epsilon)
rescale_background='max'

# whether or not to clip the image corrected for illumination. This is a boolean variable, it can be True or False.
# If True, the image after illumination correction is clipped in the min_clip_value, max_clip_value range.
# For example: when subtraction is use the result can contain negative values. It is possible to set them to 0
# by setting clip_corrected_image=True and min_clip_value=0 (irrespective of the max_clip_value)
clip_corrected_image=False

# the min value to which illumination corrected image is clipped to if clip_corrected_image is set to True
min_clip_value=0

# the max value to which illumination corrected image is clipped to if clip_corrected_image is set to True
max_clip_value=None

# whether or not to offset the background function before carrying out illumination correction.
# Two options are available: True or False
offset_background=True

# additional parameters to pass to the initial container of the illumation corrected image during the correction process
# ref to the function correct_background within the image_processing.correct_background.py script for further details.
zero_kwargs=None

# select if printing process information during background correction
verbose=True

# field of view column name in the metadata dataframe
fov_column_name = "ome_tif_file_name"

# well column name in the metadata dataframe
well_column_name = "well"

# # plate column name in the metadata dataframe
# plate_column_name = "experiment"

# within well position column name in the metadata dataframe
# this is used to identify the position of the field of view within the well
# 49 fields of view were acquired per each well, in a 7x7 grid
gridpos_column_name = "scene_name"

# what is expected to be and what will be used as null value
null_value = np.nan


# --- parameters for saving metadata within the saved fields of view after illumination correction ---
# illumination correction image - name of processing date in metadata - this is the name
# of the entry in the metadata dictionary to save within the processed image.
# The entry indicates the date when the background correction was done.
proc_img_meta_date_name = "processing_date_yymmdd"

# illumination correction image - date format in metadata - this is the format to use for indicating
# the date when the background correction was done in the metadata saved within the processed image
processing_date_format = '%y%m%d'

# illumination correction image - data type in metadata - this is the entry to use for indicating
# the data type of the illumination corrected image in the metadata saved within the processed image
proc_img_meta_dtype_name = 'dtype'

# illumination correction image - illumination correction method in metadata - this is the entry to use for indicating
# the method used for illumination correction in the metadata saved within the processed image
illum_corr_method_metadata_entry = "illumination_correction_method"

# illumination correction image - illumination correction offset in metadata - this is the entry to use for indicating
# the offset used for illumination correction in the metadata saved within the processed image
illum_corr_offset_metadata_entry = "illumination_correction_offset"

# illumination correction image - illumination correction rescaling in metadata - this is the entry to use for indicating
# in the metadata saved within the processed image, whether or not the background function is rescaled when doing illumination correction
illum_corr_rescale_metadata_entry = "illumination_correction_rescale_background"

# illumination correction image - illumination correction clipping in metadata - this is the entry to use for indicating
# in the metadata saved within the processed image, whether or not the illumination corrected image is clipped
illum_corr_clipping_metadata_entry = "illumination_correction_clipping"

# illumination correction image - illumination correction clipping min value in metadata - this is the entry to use for
# indicating in the metadata saved within the processed image, what was the min value used for clipping (if clipping was performed)
illum_corr_clip_min_value_metadata_entry = "illumination_correction_min_clip_value"

# illumination correction image - illumination correction clipping max value in metadata - this is the entry to use for
# indicating in the metadata saved within the processed image, what was the max value used for clipping (if clipping was performed)
illum_corr_clip_max_value_metadata_entry = "illumination_correction_max_clip_value"

# illumination correction image - illumination correction offset_background in metadata - this is the entry to use for
# indicating in the metadata saved within the processed image, if the offset is subtracted to the background function
illum_corr_offset_background_metadata_entry = "illumination_correction_offset_background"

# indicate the photometric interpretation to be used when saving the ome.tif files
# NOTE: at the moment, only 'minisblack' has been tested
photometric = 'minisblack'

# indicate whether to save the background function image with ImageJ compatible
save_imagej_compatible = True



# --- parameters for metadata dataframe updating ---
# column name word separator - this is the separator to use for separating the different parts of
# the column names to be added to the metadata dataframe
column_name_separator = "_"

# channel name separator - this is the separator to use for separating the channel name from the rest of
# the column name to be added to the metadata dataframe.
ch_name_separator = "-"

# illumination correction metadata dataframe - computation date column name - this is the name of the column
# to be added to the metadata dataframe to indicate the day when the illumination correction was computed.
illum_correct_df_date_clm_name = f"illumination{column_name_separator}correction{column_name_separator}date"

# illumination correction metadata dataframe - computation date format - this is the format to be used for
# indicating the date when the illumination correction was computed. This is used for saving the date in the
# metadata dataframe
illum_correct_df_meta_date_format = '%y%m%d'

# illumination correction metadata dataframe - corrected file column name - this is the name of the column
# to be added to the metadata dataframe to indicate the name used for saving the illumination corrected file.
illum_correct_df_file_name_clm_name = f"illumination{column_name_separator}correction{column_name_separator}file{column_name_separator}name"

# illumination correction metadata dataframe - method for illumination correction column name - this is the name
# of the column to be added to the metadata dataframe to indicate the method used for illumination correction.
illum_correct_df_method_clm_name = f"illumination{column_name_separator}correction{column_name_separator}method"

# illumination correction metadata dataframe - offset for illumination correction column name - this is the name
# of the column to be added to the metadata dataframe to indicate the offset used for illumination correction.
illum_correct_df_offset_clm_name = f"illumination{column_name_separator}correction{column_name_separator}offset"

# illumination correction metadata dataframe - rescale for illumination correction column name - this is the name
# of the column to be added to the metadata dataframe to indicate if the background function was rescaled when
# doing illumination correction and the method used
illum_correct_df_rescale_clm_name = f"illumination{column_name_separator}correction{column_name_separator}rescale{column_name_separator}background"

# illumination correction metadata dataframe - clipping for illumination correction column name - this is the name
# of the column to be added to the metadata dataframe to indicate if doing illumination correction the corrected image
# has been clipped.
illum_correct_df_clipping_clm_name = f"illumination{column_name_separator}correction{column_name_separator}clip{column_name_separator}output"

# illumination correction metadata dataframe - clipping min value for illumination correction column name - this is
# the name of the column to be added to the metadata dataframe to indicate what was the minimum value used
# for clipping the corrected image (if clipping was done).
illum_correct_df_clip_min_value_clm_name = f"illumination{column_name_separator}correction{column_name_separator}min{column_name_separator}clip{column_name_separator}value"

# illumination correction metadata dataframe - clipping max value for illumination correction column name - this is
# the name of the column to be added to the metadata dataframe to indicate what was the maximum value used
# for clipping the corrected image (if clipping was done).
illum_correct_df_clip_max_value_clm_name = f"illumination{column_name_separator}correction{column_name_separator}max{column_name_separator}clip{column_name_separator}value"

# illumination correction metadata dataframe - offset_background for illumination correction column name - this is
# the name of the column to be added to the metadata dataframe to indicate if doing illumination correction the
# background function has been offsetted.
illum_correct_df_offset_background_clm_name = f"illumination{column_name_separator}correction{column_name_separator}offset{column_name_separator}background"


# --- parameters for file saving ---
# separator used for saved file names
save_file_name_separator = '_'

# project
project_name = "ACID"

# include indexes when saving pandas dataframes as csv files
save_csv_index = False # if False, the index will not be saved as a separate column in the csv file

# illumination correction image name - savingword - this is the word to use in the field of view file name
# to indicate that the file is an illumination corrected field of view
fov_illumin_corrected_savingword = 'bg'

# ome suffix - used to save ome.tif files
ome_suffix = ".ome.tif"

# processing metadata dataframe name - savingword
metadata_savingword = "metadata"

# processing metadata dataframe name - file suffix
metadata_file_suffix = f"part{save_file_name_separator}4extra.csv"

# processing metadata dataframe name - date format
metadata_date_format = '%Y%m%d'

# hyperparameters dataframe name - date format
hyperparameters_date_format = '%Y%m%d-%H%M%S'

# hyperparameters dataframe name - savingword
hyperparameters_savingword = "hyperparameters"

# hyperparameters dataframe name - file suffix
hyperparameters_file_suffix = f"part{save_file_name_separator}4extra.csv"


# --- parameters for displaying the results ---
# graph saving date format
graph_date_format = '%Y%m%d'

# graphs suffix
graph_suffix = f".png"

# graph savingword
graph_savingword = f"illumination{save_file_name_separator}correction"



# --- parameters for saving secondary information ---
# indicate the name of the directory for saving secondary outputs -
# this directory is used to store the hyperparameters used per each run of the pipeline
secondary_output_directory = "secondary_output"
exist_ok = True # if the secondary output directory already exists, do not raise an error

# %% [markdown]
# ### Create output directory and secondary output directory if they don't exist
#
# ##### Output directory stores the computed background function
# ##### Secondary output directory is used to store the hyperparameters used per each run of the pipeline
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# create the output_directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory, exist_ok=exist_ok)

# create the path to secondary_output directory
secondary_output_path = os.path.join(os.getcwd(), secondary_output_directory)

# create the secondary_output directory if it doesn't exist
if not os.path.exists(secondary_output_path):
    os.makedirs(secondary_output_path, exist_ok=exist_ok)

# %% [markdown]
# #### Open the metadata dataframe - this is expected to be the output of part 3
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# check if using the default metadata data frame (the most recently saved)
if metadata_file_name==None or metadata_file_name.lower()=="default" or metadata_file_name=="":
    
    # import target files in the metadata_directory
    metadata_files = listdirNHF(metadata_directory,
                                target=default_metadata_file_target,
                                exclude=default_metadata_file_exclude)
    
    # get the default metadata file
    metadata_file_name = default_file_name(file_list=metadata_files,
                                           from_file_name=metadata_from_file_name,
                                           directory_path=metadata_directory,
                                           separator=metadata_default_separator,
                                           date_position=metadata_default_date_position,
                                           date_format=metadata_default_date_format,
                                           reverse=metadata_default_reverse)
    
    print(f"using {metadata_file_name} as default metadata file")


# open the metadata file
metadata_df_i = pd.read_csv(os.path.join(metadata_directory, metadata_file_name))

# copy metadata_df
metadata_df = metadata_df_i.copy()

# # display the metadata dataframe
# metadata_df

# %% [markdown]
# #### Select test data set - NOTE: the metadata_df is updated into a metadata_df which does not contain the train data
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# Select only the train set and update metadata_df
metadata_df = metadata_df[metadata_df[is_train_column] == test_val]

# assert proper selection of train set
assert metadata_df.shape[0] > 0, "No rows in metadata_df belong to the train set."
assert all(metadata_df[is_train_column] == test_val), "Not all rows in metadata_df belong to the train set."

# Display the metadata dataframe
metadata_df
# Out:
#                                   raw_file_name scene_name  \
# 2     H7_DENV2_MOI1_30h_fixed_stained_well1.nd2         A3
# 3     H7_DENV2_MOI1_30h_fixed_stained_well1.nd2         A4
# 6     H7_DENV2_MOI1_30h_fixed_stained_well1.nd2         A7
# 10    H7_DENV2_MOI1_30h_fixed_stained_well1.nd2         B4
# 12    H7_DENV2_MOI1_30h_fixed_stained_well1.nd2         B2
# ...                                         ...        ...
# 1167  H7_DENV2_MOI1_40h_fixed_stained_well8.nd2         F2
# 1168  H7_DENV2_MOI1_40h_fixed_stained_well8.nd2         F1
# 1169  H7_DENV2_MOI1_40h_fixed_stained_well8.nd2         G1
# 1171  H7_DENV2_MOI1_40h_fixed_stained_well8.nd2         G3
# 1173  H7_DENV2_MOI1_40h_fixed_stained_well8.nd2         G5
#
#       processing_date_yymmdd  \
# 2                     251211
# 3                     251211
# 6                     251211
# 10                    251211
# 12                    251211
# ...                      ...
# 1167                  251211
# 1168                  251211
# 1169                  251211
# 1171                  251211
# 1173                  251211
#
#                                       ome_tif_file_name  \
# 2     H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_A3...
# 3     H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_A4...
# 6     H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_A7...
# 10    H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_B4...
# 12    H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_B2...
# ...                                                 ...
# 1167  H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_F2...
# 1168  H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_F1...
# 1169  H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_G1...
# 1171  H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_G3...
# 1173  H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_G5...
#
#                                                location  \
# 2     Center for Integrative Infectious Disease Rese...
# 3     Center for Integrative Infectious Disease Rese...
# 6     Center for Integrative Infectious Disease Rese...
# 10    Center for Integrative Infectious Disease Rese...
# 12    Center for Integrative Infectious Disease Rese...
# ...                                                 ...
# 1167  Center for Integrative Infectious Disease Rese...
# 1168  Center for Integrative Infectious Disease Rese...
# 1169  Center for Integrative Infectious Disease Rese...
# 1171  Center for Integrative Infectious Disease Rese...
# 1173  Center for Integrative Infectious Disease Rese...
#
#                               microscope  \
# 2     Nikon Ti2 - CSU-W1 - spinning disc
# 3     Nikon Ti2 - CSU-W1 - spinning disc
# 6     Nikon Ti2 - CSU-W1 - spinning disc
# 10    Nikon Ti2 - CSU-W1 - spinning disc
# 12    Nikon Ti2 - CSU-W1 - spinning disc
# ...                                  ...
# 1167  Nikon Ti2 - CSU-W1 - spinning disc
# 1168  Nikon Ti2 - CSU-W1 - spinning disc
# 1169  Nikon Ti2 - CSU-W1 - spinning disc
# 1171  Nikon Ti2 - CSU-W1 - spinning disc
# 1173  Nikon Ti2 - CSU-W1 - spinning disc
#
#                                    objective experiment condition1  \
# 2     Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.2         H7
# 3     Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.2         H7
# 6     Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.2         H7
# 10    Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.2         H7
# 12    Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.2         H7
# ...                                      ...        ...        ...
# 1167  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4         H7
# 1168  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4         H7
# 1169  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4         H7
# 1171  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4         H7
# 1173  Nikon Apochromat Lambda-S 60x/1.40 Oil      A07.4         H7
#
#      infectious_organism  ... size_c size_z size_y physical_size_y size_x  \
# 2                  DENV2  ...      5      1   1024           0.325   1024
# 3                  DENV2  ...      5      1   1024           0.325   1024
# 6                  DENV2  ...      5      1   1024           0.325   1024
# 10                 DENV2  ...      5      1   1024           0.325   1024
# 12                 DENV2  ...      5      1   1024           0.325   1024
# ...                  ...  ...    ...    ...    ...             ...    ...
# 1167               DENV2  ...      5      1   1024           0.325   1024
# 1168               DENV2  ...      5      1   1024           0.325   1024
# 1169               DENV2  ...      5      1   1024           0.325   1024
# 1171               DENV2  ...      5      1   1024           0.325   1024
# 1173               DENV2  ...      5      1   1024           0.325   1024
#
#      physical_size_x dims_order int_well           treatment is_train
# 2              0.325        CYX        1    uninfected_nocpd        0
# 3              0.325        CYX        1    uninfected_nocpd        0
# 6              0.325        CYX        1    uninfected_nocpd        0
# 10             0.325        CYX        1    uninfected_nocpd        0
# 12             0.325        CYX        1    uninfected_nocpd        0
# ...              ...        ...      ...                 ...      ...
# 1167           0.325        CYX        8  uninfected_JNJ_A07        0
# 1168           0.325        CYX        8  uninfected_JNJ_A07        0
# 1169           0.325        CYX        8  uninfected_JNJ_A07        0
# 1171           0.325        CYX        8  uninfected_JNJ_A07        0
# 1173           0.325        CYX        8  uninfected_JNJ_A07        0
#
# [353 rows x 32 columns]

# %%
# import target files in the background_directory
background_files = listdirNHF(background_directory,
                              target=default_bg_funct_file_target,
                              exclude=default_bg_funct_file_exclude)

if background_function_strategy == 1:
    
    # check if using the default background function name (the most recently saved)
    if background_function_timestamp==None or background_function_timestamp.lower()=="default" or background_function_timestamp=="":
        bg_funct_file_name = default_file_name(file_list=background_files,
                                                       from_file_name=background_from_file_name,
                                                       directory_path=background_directory,
                                                       separator=background_default_separator,
                                                       date_position=background_default_date_position,
                                                       date_format=background_default_date_format,
                                                       reverse=background_default_reverse)
        print(f"using {bg_funct_file_name} as default background function file")
    
    else:
        # select the background function file with the timestamp indicated in background_function_timestamp
        bg_funct_file_name = [f for f in background_files if background_function_timestamp in f][0]

    # open the background function
    background_function = tifffile.imread(os.path.join(background_directory, bg_funct_file_name))


elif background_function_strategy in [2, 3]:
    # check if using the default background function name (the most recently saved)
    if background_function_timestamp==None or background_function_timestamp.lower()=="default" or background_function_timestamp=="":
        bg_funct_file_names = default_multifile_name(file_list=background_files,
                                                       from_file_name=background_from_file_name,
                                                       directory_path=background_directory,
                                                       separator=background_default_separator,
                                                       date_position=background_default_date_position,
                                                       date_format=background_default_date_format,
                                                       reverse=background_default_reverse)
        
        print(f"using the following files as default background function files:")
        for f in bg_funct_file_names:
            print(f)
    else:
        # select the background function files with the timestamp indicated in background_function_timestamp
        bg_funct_file_names = [f for f in background_files if background_function_timestamp in f]


    if background_function_strategy == 2:
        # get unique wells from the metadata dataframe
        unique_conditions = metadata_df[well_column_name].unique()
    elif background_function_strategy == 3:
        # get unique grid positions from the metadata dataframe
        unique_conditions = metadata_df[gridpos_column_name].unique()

    # assert that the number of background function files matches the number of unique wells
    assert len(bg_funct_file_names) == len(unique_conditions), f"The number of background function files ({len(bg_funct_file_names)}) does not match the number of unique conditions ({len(unique_conditions)}). Please check the background function directory and the metadata dataframe."
    
    # map the background function files to the unique conditions (wells or grid positions depending on the strategy)
    bg_funct_file_dict = map_image_to_condition(condition_list=unique_conditions,
                                                image_file_names=bg_funct_file_names,
                                                assert_file_number=background_default_assert_file_number,
                                                number_of_files_expected=background_default_number_of_files_expected)


else:
    raise ValueError(f"Invalid background function strategy: {background_function_strategy}. Please select either 1, 2 or 3.")
# Out:
# using 20260318_ACID_background.ome.tif as default background function file

# %% [markdown]
# #### Get the shape and the number of channels of the fields of view - NOTE: it is assumed that all fields of view in the dataset have the same shape and number of channels
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# get the shape of the individual fields of view, the number of channels and the shape of individual channels
fov_shape, num_channels, shape_of_channels = get_fov_ch_shape(metadata_df,
                                                              fov_directory,
                                                              fov_clm=fov_column_name,
                                                              channel_axis=channel_axis,
                                                              null_value=null_value)
# Out:
# field of view shape: (5, 1024, 1024)
# number of channels found: 5
# shape of channels: (1024, 1024)

# %% [markdown]
# ### MAIN LOOP

# %%
# initialize lists to collect processing metadata for updating - this will be used to update the metadata df
illum_correct_date_collection = []
illum_correct_file_name_collection = []
illum_correct_method_collection = []
illum_correct_offset_collection = []
illum_correct_rescale_collection = []
illum_correct_clipping_collection = []
illum_correct_clip_min_value_collection = []
illum_correct_clip_max_value_collection = []
illum_correct_offset_background_collection = []


# iterate through the rows of the metadata dataframe
for i in metadata_df.index:

    print("---------    ---------")
    
    # ---------
    # OPEN FIELD OF VIEW
    # ---------

    # get the field of view file
    field_of_view_file = metadata_df.loc[i, fov_column_name]

    print(f"working on {field_of_view_file}")

    # form full path to the field of view
    field_of_view_path = os.path.join(fov_directory, str(field_of_view_file))

    # try to open the field of view
    try:

        # open the field of view
        field_of_view = tifffile.imread(field_of_view_path)

    except:
        print(f"can't open {field_of_view_file}, skipping illumination correction")

        # add null_value to the collection lists
        illum_correct_date_collection.append(null_value)
        illum_correct_file_name_collection.append(null_value)
        illum_correct_method_collection.append(null_value)
        illum_correct_offset_collection.append(null_value)
        illum_correct_rescale_collection.append(null_value)
        illum_correct_clipping_collection.append(null_value)
        illum_correct_clip_min_value_collection.append(null_value)
        illum_correct_clip_max_value_collection.append(null_value)
        illum_correct_offset_background_collection.append(null_value)

        continue
    
    # ---------
    # UPDATE IMAGE METADATA
    # ---------
    # get field of view metadata
    field_of_view_metadata = extract_ometif_imagej_metadata(field_of_view_path)
    
    # update the image metadata data
    # first, update the processing date and the data type - NOTE: to stay consistent with how the
    # metadata is generated, first a dummy dictionary is created, which is converted as the orginal one,
    # before extracting the sole key
    processing_date_metadata_entry = list(imagej_compatible_metadata_dict({proc_img_meta_date_name:"dummy"}))[0]
    dtype_metadata_entry = list(imagej_compatible_metadata_dict({proc_img_meta_dtype_name:"dummy"}))[0]
    field_of_view_metadata[processing_date_metadata_entry]=datetime.datetime.now().strftime(processing_date_format)
    field_of_view_metadata[dtype_metadata_entry]=output_dtype

    # second, add information about the illumination correction process
    # form a dictionary storing the information to add to the metadata
    field_of_view_illcorr_metadata = {illum_corr_method_metadata_entry:method,
                                      illum_corr_offset_metadata_entry:offset,
                                      illum_corr_rescale_metadata_entry:rescale_background,
                                      illum_corr_clipping_metadata_entry:clip_corrected_image,
                                      illum_corr_clip_min_value_metadata_entry:min_clip_value,
                                      illum_corr_clip_max_value_metadata_entry:max_clip_value,
                                      illum_corr_offset_background_metadata_entry:offset_background}
    
    # convert the dictionary so that entries are distinguishable from default ones
    field_of_view_illcorr_metadata = imagej_compatible_metadata_dict(field_of_view_illcorr_metadata)

    # update the metadata dictionary by adding the new information on illumination correction
    for k in field_of_view_illcorr_metadata:
        field_of_view_metadata[k]=field_of_view_illcorr_metadata[k]
    
    # ---------
    # STRATEGY 1
    # ---------
    if background_function_strategy==1:
            
        # get the illumination corrected image
        illum_correct_field_of_view = correct_background(field_of_view,
                                                         background=background_function,
                                                         method=method,
                                                         channel_axis=channel_axis,
                                                         offset=offset,
                                                         epsilon=epsilon,
                                                         working_dtype=working_dtype,
                                                         output_dtype=output_dtype,
                                                         rescale_background=rescale_background,
                                                         clip_corrected_image=clip_corrected_image,
                                                         min_clip_value=min_clip_value,
                                                         max_clip_value=max_clip_value,
                                                         zero_kwargs=zero_kwargs,
                                                         offset_background=offset_background,
                                                         verbose=verbose)

        # save the corrected image
        # form the saving name of the file
        save_file_name = f"{field_of_view_file.removesuffix(ome_suffix)}{save_file_name_separator}{fov_illumin_corrected_savingword}{ome_suffix}"

        tifffile_save_ometiff(os.path.join(output_directory,save_file_name),
                                  data=illum_correct_field_of_view,
                                  imagej=save_imagej_compatible,
                                  photometric=photometric,
                                  metadata=field_of_view_illcorr_metadata)
        
        # update the metadata collection lists
        # add null_value to the collection lists
        illum_correct_date_collection.append(datetime.datetime.now().strftime(illum_correct_df_meta_date_format))
        illum_correct_file_name_collection.append(save_file_name)
        illum_correct_method_collection.append(method)
        illum_correct_offset_collection.append(offset)
        illum_correct_rescale_collection.append(rescale_background)
        illum_correct_clipping_collection.append(clip_corrected_image)
        illum_correct_clip_min_value_collection.append(min_clip_value)
        illum_correct_clip_max_value_collection.append(max_clip_value)
        illum_correct_offset_background_collection.append(offset_background)

        # print progress update
        print("illumation correction done. File saved. Metadata updated")

    # ---------
    # STRATEGY 2
    # ---------
    elif background_function_strategy==2:
          
        # get well
        fov_well = metadata_df.loc[i, well_column_name]

        # map the field of view with its background function
        well_background_function = bg_funct_file_dict[fov_well]
        
        # get the illumination corrected image
        illum_correct_field_of_view_well = correct_background(field_of_view,
                                                         background=well_background_function,
                                                         method=method,
                                                         channel_axis=channel_axis,
                                                         offset=offset,
                                                         epsilon=epsilon,
                                                         working_dtype=working_dtype,
                                                         output_dtype=output_dtype,
                                                         rescale_background=rescale_background,
                                                         clip_corrected_image=clip_corrected_image,
                                                         min_clip_value=min_clip_value,
                                                         max_clip_value=max_clip_value,
                                                         zero_kwargs=zero_kwargs,
                                                         offset_background=offset_background,
                                                         verbose=verbose)

        # save the corrected image
        # form the saving name of the file
        save_file_name_well = f"{field_of_view_file.removesuffix(ome_suffix)}{save_file_name_separator}{fov_illumin_corrected_savingword}{ome_suffix}"

        tifffile_save_ometiff(os.path.join(output_directory,save_file_name_well),
                                  data=illum_correct_field_of_view_well,
                                  imagej=save_imagej_compatible,
                                  photometric=photometric,
                                  metadata=field_of_view_illcorr_metadata)
        
        # update the metadata collection lists
        # add null_value to the collection lists
        illum_correct_date_collection.append(datetime.datetime.now().strftime(illum_correct_df_meta_date_format))
        illum_correct_file_name_collection.append(save_file_name_well)
        illum_correct_method_collection.append(method)
        illum_correct_offset_collection.append(offset)
        illum_correct_rescale_collection.append(rescale_background)
        illum_correct_clipping_collection.append(clip_corrected_image)
        illum_correct_clip_min_value_collection.append(min_clip_value)
        illum_correct_clip_max_value_collection.append(max_clip_value)
        illum_correct_offset_background_collection.append(offset_background)

        # print progress update
        print("illumation correction done. File saved. Metadata updated")

    # ---------
    # STRATEGY 3
    # ---------
    elif background_function_strategy==3:

        # get grid-position
        fov_scene = metadata_df.loc[i, gridpos_column_name]

        # map the field of view with its background function
        scene_background_function = bg_funct_file_dict[fov_scene]

        # get the illumination corrected image
        illum_correct_field_of_view_scene = correct_background(field_of_view,
                                                               background=scene_background_function,
                                                         method=method,
                                                         channel_axis=channel_axis,
                                                         offset=offset,
                                                         epsilon=epsilon,
                                                         working_dtype=working_dtype,
                                                         output_dtype=output_dtype,
                                                         rescale_background=rescale_background,
                                                         clip_corrected_image=clip_corrected_image,
                                                         min_clip_value=min_clip_value,
                                                         max_clip_value=max_clip_value,
                                                         zero_kwargs=zero_kwargs,
                                                         offset_background=offset_background,
                                                         verbose=verbose)

        # save the corrected image
        # form the saving name of the file
        save_file_name_scene = f"{field_of_view_file.removesuffix(ome_suffix)}{save_file_name_separator}{fov_illumin_corrected_savingword}{ome_suffix}"

        tifffile_save_ometiff(os.path.join(output_directory,save_file_name_scene),
                                  data=illum_correct_field_of_view_scene,
                                  imagej=save_imagej_compatible,
                                  photometric=photometric,
                                  metadata=field_of_view_illcorr_metadata)
        
        # update the metadata collection lists
        # add null_value to the collection lists
        illum_correct_date_collection.append(datetime.datetime.now().strftime(illum_correct_df_meta_date_format))
        illum_correct_file_name_collection.append(save_file_name_scene)
        illum_correct_method_collection.append(method)
        illum_correct_offset_collection.append(offset)
        illum_correct_rescale_collection.append(rescale_background)
        illum_correct_clipping_collection.append(clip_corrected_image)
        illum_correct_clip_min_value_collection.append(min_clip_value)
        illum_correct_clip_max_value_collection.append(max_clip_value)
        illum_correct_offset_background_collection.append(offset_background)
        
        # print progress update
        print("illumation correction done. File saved. Metadata updated")

    else:
        raise ValueError("background_function_strategy must be 1, 2 or 3")

# print progress update
print("illumination correction finished")

# ---------
# UPDATE PROCESSING METADATA DATA FRAME
# ---------
metadata_df[illum_correct_df_date_clm_name] = illum_correct_date_collection
metadata_df[illum_correct_df_file_name_clm_name] = illum_correct_file_name_collection
metadata_df[illum_correct_df_method_clm_name] = illum_correct_method_collection
metadata_df[illum_correct_df_offset_clm_name] = illum_correct_offset_collection
metadata_df[illum_correct_df_rescale_clm_name] = illum_correct_rescale_collection
metadata_df[illum_correct_df_clipping_clm_name] = illum_correct_clipping_collection
metadata_df[illum_correct_df_clip_min_value_clm_name] = illum_correct_clip_min_value_collection
metadata_df[illum_correct_df_clip_max_value_clm_name] = illum_correct_clip_max_value_collection
metadata_df[illum_correct_df_offset_background_clm_name] = illum_correct_offset_background_collection

# save the updated metadata dataframe as a csv file
metadata_df_name = f"{datetime.datetime.now().strftime(metadata_date_format)}{save_file_name_separator}{project_name}{save_file_name_separator}{metadata_savingword}{save_file_name_separator}{metadata_file_suffix}"
metadata_df.to_csv(os.path.join(metadata_directory, metadata_df_name), index=save_csv_index)

# print progress update
print("metadata saved")
print("finished")
# Out:
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_A3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 415.0, image max: 2687.0
# after correction image min: 21.777761459350586, image max: 2499.3408203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 21.777761459350586, image max: 2499.3408203125
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 16520.0
# after correction image min: 46.28961944580078, image max: 19132.005859375
# changing the data type of the output/corrected image
# final data type: float32, image min: 46.28961944580078, image max: 19132.005859375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 451.0, image max: 20988.0
# after correction image min: 74.99874114990234, image max: 22330.79296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 74.99874114990234, image max: 22330.79296875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 427.0, image max: 12562.0
# after correction image min: 29.345020294189453, image max: 12727.466796875
# changing the data type of the output/corrected image
# final data type: float32, image min: 29.345020294189453, image max: 12727.466796875
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 9192.0, image max: 39531.0
# after correction image min: 9400.181640625, image max: 39454.69921875
# changing the data type of the output/corrected image
# final data type: float32, image min: 9400.181640625, image max: 39454.69921875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_A4.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 429.0, image max: 2752.0
# after correction image min: 40.41984176635742, image max: 2493.83056640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 40.41984176635742, image max: 2493.83056640625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 455.0, image max: 34891.0
# after correction image min: 64.85652923583984, image max: 38915.32421875
# changing the data type of the output/corrected image
# final data type: float32, image min: 64.85652923583984, image max: 38915.32421875
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 445.0, image max: 12302.0
# after correction image min: 58.4924201965332, image max: 17081.318359375
# changing the data type of the output/corrected image
# final data type: float32, image min: 58.4924201965332, image max: 17081.318359375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 734.0
# after correction image min: 30.82272720336914, image max: 339.8294372558594
# changing the data type of the output/corrected image
# final data type: float32, image min: 30.82272720336914, image max: 339.8294372558594
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 10503.0, image max: 39337.0
# after correction image min: 10807.7958984375, image max: 41687.23046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 10807.7958984375, image max: 41687.23046875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_A7.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 428.0, image max: 8813.0
# after correction image min: 32.687767028808594, image max: 9010.875
# changing the data type of the output/corrected image
# final data type: float32, image min: 32.687767028808594, image max: 9010.875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 452.0, image max: 20075.0
# after correction image min: 77.72073364257812, image max: 24845.7890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 77.72073364257812, image max: 24845.7890625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 445.0, image max: 19658.0
# after correction image min: 72.01510620117188, image max: 22261.53125
# changing the data type of the output/corrected image
# final data type: float32, image min: 72.01510620117188, image max: 22261.53125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 785.0
# after correction image min: 27.36896324157715, image max: 387.52587890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 27.36896324157715, image max: 387.52587890625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 9698.0, image max: 56406.0
# after correction image min: 9608.0400390625, image max: 56735.52734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 9608.0400390625, image max: 56735.52734375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_B4.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 422.0, image max: 2773.0
# after correction image min: 29.708694458007812, image max: 2762.1162109375
# changing the data type of the output/corrected image
# final data type: float32, image min: 29.708694458007812, image max: 2762.1162109375
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 19359.0
# after correction image min: 50.17159652709961, image max: 19989.583984375
# changing the data type of the output/corrected image
# final data type: float32, image min: 50.17159652709961, image max: 19989.583984375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 15376.0
# after correction image min: 55.26728820800781, image max: 19224.748046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 55.26728820800781, image max: 19224.748046875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 426.0, image max: 641.0
# after correction image min: 31.739843368530273, image max: 243.78146362304688
# changing the data type of the output/corrected image
# final data type: float32, image min: 31.739843368530273, image max: 243.78146362304688
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 9450.0, image max: 43511.0
# after correction image min: 9765.25390625, image max: 46326.5234375
# changing the data type of the output/corrected image
# final data type: float32, image min: 9765.25390625, image max: 46326.5234375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_B2.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 3625.0
# after correction image min: 36.421207427978516, image max: 3339.461181640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 36.421207427978516, image max: 3339.461181640625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 454.0, image max: 55607.0
# after correction image min: 63.86347198486328, image max: 59130.26953125
# changing the data type of the output/corrected image
# final data type: float32, image min: 63.86347198486328, image max: 59130.26953125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 449.0, image max: 15035.0
# after correction image min: 63.87722396850586, image max: 17392.693359375
# changing the data type of the output/corrected image
# final data type: float32, image min: 63.87722396850586, image max: 17392.693359375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 428.0, image max: 633.0
# after correction image min: 34.30673599243164, image max: 235.24008178710938
# changing the data type of the output/corrected image
# final data type: float32, image min: 34.30673599243164, image max: 235.24008178710938
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 9447.0, image max: 36969.0
# after correction image min: 9540.41015625, image max: 37148.17578125
# changing the data type of the output/corrected image
# final data type: float32, image min: 9540.41015625, image max: 37148.17578125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_D5.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 427.0, image max: 3096.0
# after correction image min: 38.95011901855469, image max: 3084.787109375
# changing the data type of the output/corrected image
# final data type: float32, image min: 38.95011901855469, image max: 3084.787109375
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 446.0, image max: 7901.0
# after correction image min: 67.46955108642578, image max: 8305.6923828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 67.46955108642578, image max: 8305.6923828125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 445.0, image max: 24495.0
# after correction image min: 83.10188293457031, image max: 33436.95703125
# changing the data type of the output/corrected image
# final data type: float32, image min: 83.10188293457031, image max: 33436.95703125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 419.0, image max: 631.0
# after correction image min: 23.53673553466797, image max: 236.12413024902344
# changing the data type of the output/corrected image
# final data type: float32, image min: 23.53673553466797, image max: 236.12413024902344
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 8593.0, image max: 49478.0
# after correction image min: 8564.80078125, image max: 50119.37890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 8564.80078125, image max: 50119.37890625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_D3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 416.0, image max: 4742.0
# after correction image min: 22.90672492980957, image max: 4468.97119140625
# changing the data type of the output/corrected image
# final data type: float32, image min: 22.90672492980957, image max: 4468.97119140625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 452.0, image max: 14613.0
# after correction image min: 72.94818878173828, image max: 17299.931640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 72.94818878173828, image max: 17299.931640625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 452.0, image max: 17976.0
# after correction image min: 65.94390106201172, image max: 23859.458984375
# changing the data type of the output/corrected image
# final data type: float32, image min: 65.94390106201172, image max: 23859.458984375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 428.0, image max: 1782.0
# after correction image min: 32.0546760559082, image max: 1431.432861328125
# changing the data type of the output/corrected image
# final data type: float32, image min: 32.0546760559082, image max: 1431.432861328125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 8396.0, image max: 36986.0
# after correction image min: 8378.5234375, image max: 39392.65234375
# changing the data type of the output/corrected image
# final data type: float32, image min: 8378.5234375, image max: 39392.65234375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_D1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 424.0, image max: 5652.0
# after correction image min: 35.05415344238281, image max: 5785.86669921875
# changing the data type of the output/corrected image
# final data type: float32, image min: 35.05415344238281, image max: 5785.86669921875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 453.0, image max: 29027.0
# after correction image min: 68.5885009765625, image max: 29284.91796875
# changing the data type of the output/corrected image
# final data type: float32, image min: 68.5885009765625, image max: 29284.91796875
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 443.0, image max: 14147.0
# after correction image min: 59.1611442565918, image max: 17546.525390625
# changing the data type of the output/corrected image
# final data type: float32, image min: 59.1611442565918, image max: 17546.525390625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 426.0, image max: 634.0
# after correction image min: 31.759666442871094, image max: 236.79367065429688
# changing the data type of the output/corrected image
# final data type: float32, image min: 31.759666442871094, image max: 236.79367065429688
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 7592.0, image max: 46506.0
# after correction image min: 7661.5517578125, image max: 49105.59375
# changing the data type of the output/corrected image
# final data type: float32, image min: 7661.5517578125, image max: 49105.59375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_E3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 2848.0
# after correction image min: 42.47012710571289, image max: 2576.4521484375
# changing the data type of the output/corrected image
# final data type: float32, image min: 42.47012710571289, image max: 2576.4521484375
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 447.0, image max: 15227.0
# after correction image min: 61.93357849121094, image max: 16136.3193359375
# changing the data type of the output/corrected image
# final data type: float32, image min: 61.93357849121094, image max: 16136.3193359375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 17444.0
# after correction image min: 51.161930084228516, image max: 22646.87890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 51.161930084228516, image max: 22646.87890625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 411.0, image max: 1715.0
# after correction image min: 13.44025707244873, image max: 1524.4415283203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 13.44025707244873, image max: 1524.4415283203125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 8096.0, image max: 39461.0
# after correction image min: 8145.2080078125, image max: 39821.5390625
# changing the data type of the output/corrected image
# final data type: float32, image min: 8145.2080078125, image max: 39821.5390625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_E4.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 417.0, image max: 2638.0
# after correction image min: 24.936729431152344, image max: 2387.90966796875
# changing the data type of the output/corrected image
# final data type: float32, image min: 24.936729431152344, image max: 2387.90966796875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 420.0, image max: 11340.0
# after correction image min: 29.898815155029297, image max: 11594.529296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 29.898815155029297, image max: 11594.529296875
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 436.0, image max: 15272.0
# after correction image min: 68.72811889648438, image max: 19537.041015625
# changing the data type of the output/corrected image
# final data type: float32, image min: 68.72811889648438, image max: 19537.041015625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 1143.0
# after correction image min: 31.066696166992188, image max: 755.0028686523438
# changing the data type of the output/corrected image
# final data type: float32, image min: 31.066696166992188, image max: 755.0028686523438
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 7241.0, image max: 48769.0
# after correction image min: 7447.892578125, image max: 52730.91796875
# changing the data type of the output/corrected image
# final data type: float32, image min: 7447.892578125, image max: 52730.91796875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_F3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 416.0, image max: 2931.0
# after correction image min: 23.577890396118164, image max: 2789.684326171875
# changing the data type of the output/corrected image
# final data type: float32, image min: 23.577890396118164, image max: 2789.684326171875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 451.0, image max: 38305.0
# after correction image min: 52.77242660522461, image max: 49876.2734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 52.77242660522461, image max: 49876.2734375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 464.0, image max: 13543.0
# after correction image min: 69.01538848876953, image max: 19486.083984375
# changing the data type of the output/corrected image
# final data type: float32, image min: 69.01538848876953, image max: 19486.083984375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 431.0, image max: 672.0
# after correction image min: 37.81460189819336, image max: 272.3594970703125
# changing the data type of the output/corrected image
# final data type: float32, image min: 37.81460189819336, image max: 272.3594970703125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 7878.0, image max: 40535.0
# after correction image min: 7846.42333984375, image max: 42484.15234375
# changing the data type of the output/corrected image
# final data type: float32, image min: 7846.42333984375, image max: 42484.15234375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_G2.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 421.0, image max: 3481.0
# after correction image min: 31.467655181884766, image max: 3207.79052734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 31.467655181884766, image max: 3207.79052734375
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 453.0, image max: 18416.0
# after correction image min: 77.0898666381836, image max: 18757.16015625
# changing the data type of the output/corrected image
# final data type: float32, image min: 77.0898666381836, image max: 18757.16015625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 456.0, image max: 30339.0
# after correction image min: 80.75022888183594, image max: 41998.51953125
# changing the data type of the output/corrected image
# final data type: float32, image min: 80.75022888183594, image max: 41998.51953125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 430.0, image max: 825.0
# after correction image min: 30.790416717529297, image max: 446.1547546386719
# changing the data type of the output/corrected image
# final data type: float32, image min: 30.790416717529297, image max: 446.1547546386719
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 6457.0, image max: 42124.0
# after correction image min: 6748.43603515625, image max: 44901.41015625
# changing the data type of the output/corrected image
# final data type: float32, image min: 6748.43603515625, image max: 44901.41015625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_G3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 430.0, image max: 4000.0
# after correction image min: 44.079315185546875, image max: 4627.01904296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 44.079315185546875, image max: 4627.01904296875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 441.0, image max: 21941.0
# after correction image min: 60.51726531982422, image max: 23763.423828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 60.51726531982422, image max: 23763.423828125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 455.0, image max: 20233.0
# after correction image min: 78.20050048828125, image max: 25847.4296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 78.20050048828125, image max: 25847.4296875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 417.0, image max: 927.0
# after correction image min: 20.548044204711914, image max: 536.23486328125
# changing the data type of the output/corrected image
# final data type: float32, image min: 20.548044204711914, image max: 536.23486328125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 7132.0, image max: 44603.0
# after correction image min: 7079.96337890625, image max: 46497.87109375
# changing the data type of the output/corrected image
# final data type: float32, image min: 7079.96337890625, image max: 46497.87109375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well1_A07p2_G6.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 430.0, image max: 3317.0
# after correction image min: 41.558990478515625, image max: 3303.0224609375
# changing the data type of the output/corrected image
# final data type: float32, image min: 41.558990478515625, image max: 3303.0224609375
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 465.0, image max: 6458.0
# after correction image min: 83.89326477050781, image max: 6988.447265625
# changing the data type of the output/corrected image
# final data type: float32, image min: 83.89326477050781, image max: 6988.447265625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 486.0, image max: 16868.0
# after correction image min: 103.20016479492188, image max: 26617.34375
# changing the data type of the output/corrected image
# final data type: float32, image min: 103.20016479492188, image max: 26617.34375
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 428.0, image max: 645.0
# after correction image min: 34.58382034301758, image max: 245.4761962890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 34.58382034301758, image max: 245.4761962890625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 8138.0, image max: 43591.0
# after correction image min: 8331.5380859375, image max: 46718.16015625
# changing the data type of the output/corrected image
# final data type: float32, image min: 8331.5380859375, image max: 46718.16015625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well2_A07p2_A1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 4534.0
# after correction image min: 36.77223587036133, image max: 4323.87744140625
# changing the data type of the output/corrected image
# final data type: float32, image min: 36.77223587036133, image max: 4323.87744140625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 456.0, image max: 28457.0
# after correction image min: 73.65147399902344, image max: 40549.87890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 73.65147399902344, image max: 40549.87890625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 447.0, image max: 13207.0
# after correction image min: 73.83863830566406, image max: 16130.712890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 73.83863830566406, image max: 16130.712890625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 417.0, image max: 634.0
# after correction image min: 20.868276596069336, image max: 249.14442443847656
# changing the data type of the output/corrected image
# final data type: float32, image min: 20.868276596069336, image max: 249.14442443847656
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 8788.0, image max: 55169.0
# after correction image min: 9108.337890625, image max: 56017.3203125
# changing the data type of the output/corrected image
# final data type: float32, image min: 9108.337890625, image max: 56017.3203125
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well2_A07p2_A3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 428.0, image max: 4878.0
# after correction image min: 39.165382385253906, image max: 4495.95556640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 39.165382385253906, image max: 4495.95556640625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 472.0, image max: 10754.0
# after correction image min: 88.23314666748047, image max: 12206.2138671875
# changing the data type of the output/corrected image
# final data type: float32, image min: 88.23314666748047, image max: 12206.2138671875
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 484.0, image max: 19708.0
# after correction image min: 114.1940689086914, image max: 24346.009765625
# changing the data type of the output/corrected image
# final data type: float32, image min: 114.1940689086914, image max: 24346.009765625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 419.0, image max: 740.0
# after correction image min: 23.317235946655273, image max: 341.09228515625
# changing the data type of the output/corrected image
# final data type: float32, image min: 23.317235946655273, image max: 341.09228515625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 8849.0, image max: 46817.0
# after correction image min: 8833.8466796875, image max: 49316.98046875
# changing the data type of the output/corrected image
# final data type: float32, image min: 8833.8466796875, image max: 49316.98046875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_30h_fixed_stained_well2_A07p2_A6.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 430.0, image max: 4432.0
# after correction image min: 44.36149978637695, image max: 4123.11669921875
# changing the data type of the output/corrected image
# final data type: float32, image min: 44.36149978637695, image max: 4123.11669921875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 449.0, image max: 18133.0
# after correction image min: 64.80146026611328, image max: 18120.65234375
# changing the data type of the output/corrected image
# final data type: float32, image min: 64.80146026611328, image max: 18120.65234375
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 455.0, image max: 16539.0
# after correction image min: 88.06356811523438, image max: 21692.6328125
# changing the data type of the output/corrected image
# final data type: float32, image min: 88.06356811523438, image max: 21692.6328125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 424.0, image max: 769.0
# after correction image min: 29.728612899780273, image max: 375.64642333984375
# changing the data type of the output/corrected image
# final data type: float32, image min: 29.728612899780273, image max: 375.64642333984375
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# ...
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 444.0, image max: 11964.0
# after correction image min: 65.14073944091797, image max: 12943.4296875
# changing the data type of the output/corrected image
# final data type: float32, image min: 65.14073944091797, image max: 12943.4296875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 427.0, image max: 877.0
# after correction image min: 33.23640823364258, image max: 507.0783996582031
# changing the data type of the output/corrected image
# final data type: float32, image min: 33.23640823364258, image max: 507.0783996582031
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 2046.0, image max: 8543.0
# after correction image min: 1657.083740234375, image max: 8610.1728515625
# changing the data type of the output/corrected image
# final data type: float32, image min: 1657.083740234375, image max: 8610.1728515625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_F2.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 438.0, image max: 4735.0
# after correction image min: 55.2180290222168, image max: 4713.55322265625
# changing the data type of the output/corrected image
# final data type: float32, image min: 55.2180290222168, image max: 4713.55322265625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 433.0, image max: 993.0
# after correction image min: 43.94152069091797, image max: 782.8401489257812
# changing the data type of the output/corrected image
# final data type: float32, image min: 43.94152069091797, image max: 782.8401489257812
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 451.0, image max: 11837.0
# after correction image min: 97.53893280029297, image max: 13345.3525390625
# changing the data type of the output/corrected image
# final data type: float32, image min: 97.53893280029297, image max: 13345.3525390625
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 420.0, image max: 1215.0
# after correction image min: 24.644012451171875, image max: 854.4581909179688
# changing the data type of the output/corrected image
# final data type: float32, image min: 24.644012451171875, image max: 854.4581909179688
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 1920.0, image max: 7631.0
# after correction image min: 1546.1923828125, image max: 8056.81640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 1546.1923828125, image max: 8056.81640625
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_F1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 429.0, image max: 3693.0
# after correction image min: 43.376312255859375, image max: 3596.654052734375
# changing the data type of the output/corrected image
# final data type: float32, image min: 43.376312255859375, image max: 3596.654052734375
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 441.0, image max: 5126.0
# after correction image min: 43.873756408691406, image max: 5127.25048828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 43.873756408691406, image max: 5127.25048828125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 440.0, image max: 18961.0
# after correction image min: 52.02607345581055, image max: 18903.451171875
# changing the data type of the output/corrected image
# final data type: float32, image min: 52.02607345581055, image max: 18903.451171875
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 424.0, image max: 4073.0
# after correction image min: 29.11931800842285, image max: 3986.408935546875
# changing the data type of the output/corrected image
# final data type: float32, image min: 29.11931800842285, image max: 3986.408935546875
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 1839.0, image max: 7980.0
# after correction image min: 1516.619384765625, image max: 7817.8388671875
# changing the data type of the output/corrected image
# final data type: float32, image min: 1516.619384765625, image max: 7817.8388671875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_G1.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 426.0, image max: 3862.0
# after correction image min: 37.2543830871582, image max: 3715.83056640625
# changing the data type of the output/corrected image
# final data type: float32, image min: 37.2543830871582, image max: 3715.83056640625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 448.0, image max: 8443.0
# after correction image min: 54.74938201904297, image max: 8654.611328125
# changing the data type of the output/corrected image
# final data type: float32, image min: 54.74938201904297, image max: 8654.611328125
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 443.0, image max: 17274.0
# after correction image min: 71.17195892333984, image max: 19799.970703125
# changing the data type of the output/corrected image
# final data type: float32, image min: 71.17195892333984, image max: 19799.970703125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 433.0, image max: 65535.0
# after correction image min: 40.7107048034668, image max: 65686.2890625
# changing the data type of the output/corrected image
# final data type: float32, image min: 40.7107048034668, image max: 65686.2890625
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 1712.0, image max: 6119.0
# after correction image min: 1370.270263671875, image max: 6096.24560546875
# changing the data type of the output/corrected image
# final data type: float32, image min: 1370.270263671875, image max: 6096.24560546875
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_G3.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 440.0, image max: 4067.0
# after correction image min: 54.11586380004883, image max: 3823.66015625
# changing the data type of the output/corrected image
# final data type: float32, image min: 54.11586380004883, image max: 3823.66015625
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 1247.0
# after correction image min: 40.231605529785156, image max: 910.8350219726562
# changing the data type of the output/corrected image
# final data type: float32, image min: 40.231605529785156, image max: 910.8350219726562
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 470.0, image max: 9737.0
# after correction image min: 99.4964828491211, image max: 12712.4345703125
# changing the data type of the output/corrected image
# final data type: float32, image min: 99.4964828491211, image max: 12712.4345703125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 425.0, image max: 3367.0
# after correction image min: 30.553003311157227, image max: 3184.608642578125
# changing the data type of the output/corrected image
# final data type: float32, image min: 30.553003311157227, image max: 3184.608642578125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 1770.0, image max: 7220.0
# after correction image min: 1462.166748046875, image max: 6834.53271484375
# changing the data type of the output/corrected image
# final data type: float32, image min: 1462.166748046875, image max: 6834.53271484375
# illumation correction done. File saved. Metadata updated
# ---------    ---------
# working on H7_DENV2_MOI1_40h_fixed_stained_well8_A07p4_G5.ome.tif
# background correction on axis: 0
# --- ch 0
# offsetting the background
# rescaling background with max method
# before rescaling background min: 110.8878173828125, background max: 167.21051025390625
# after rescaling background min: 0.6631629467010498, background max: 1.0
# correct background with division method
# before correction image min: 434.0, image max: 3310.0
# after correction image min: 49.578529357910156, image max: 3153.272216796875
# changing the data type of the output/corrected image
# final data type: float32, image min: 49.578529357910156, image max: 3153.272216796875
# --- ch 1
# offsetting the background
# rescaling background with max method
# before rescaling background min: 141.260009765625, background max: 219.0555419921875
# after rescaling background min: 0.6448593139648438, background max: 1.0
# correct background with division method
# before correction image min: 436.0, image max: 2036.0
# after correction image min: 46.9000244140625, image max: 1636.375244140625
# changing the data type of the output/corrected image
# final data type: float32, image min: 46.9000244140625, image max: 1636.375244140625
# --- ch 2
# offsetting the background
# rescaling background with max method
# before rescaling background min: 363.7740478515625, background max: 742.01708984375
# after rescaling background min: 0.49025022983551025, background max: 1.0
# correct background with division method
# before correction image min: 451.0, image max: 11206.0
# after correction image min: 52.44440841674805, image max: 15371.1923828125
# changing the data type of the output/corrected image
# final data type: float32, image min: 52.44440841674805, image max: 15371.1923828125
# --- ch 3
# offsetting the background
# rescaling background with max method
# before rescaling background min: 96.27365112304688, background max: 120.09515380859375
# after rescaling background min: 0.8016447424888611, background max: 1.0
# correct background with division method
# before correction image min: 427.0, image max: 65535.0
# after correction image min: 33.496803283691406, image max: 65948.0078125
# changing the data type of the output/corrected image
# final data type: float32, image min: 33.496803283691406, image max: 65948.0078125
# --- ch 4
# offsetting the background
# rescaling background with max method
# before rescaling background min: 2948.773193359375, background max: 3343.700927734375
# after rescaling background min: 0.8818890452384949, background max: 1.0
# correct background with division method
# before correction image min: 1870.0, image max: 6252.0
# after correction image min: 1521.081787109375, image max: 6144.15185546875
# changing the data type of the output/corrected image
# final data type: float32, image min: 1521.081787109375, image max: 6144.15185546875
# illumation correction done. File saved. Metadata updated
# illumination correction finished
# metadata saved
# finished

# %% [markdown]
# ### Display the result

# %%
import random
# randomly select a field of view before and after correction
random_field_of_view_idx = random.choice(list(metadata_df.index))
random_field_of_view_name = metadata_df.loc[random_field_of_view_idx, fov_column_name]
random_field_of_view_corrected_name = metadata_df.loc[random_field_of_view_idx, illum_correct_df_file_name_clm_name]
print(f"""
displaying the result for:
{random_field_of_view_name}
{random_field_of_view_corrected_name}
""")
random_field_of_view = tifffile.imread(os.path.join(fov_directory, random_field_of_view_name))
random_field_of_view_corrected = tifffile.imread(os.path.join(output_directory, random_field_of_view_corrected_name))


fig, axes = plt.subplots(num_channels, 4, figsize=(12, 3 * num_channels))

plot_image_channels_and_diagonals(
    random_field_of_view,
    random_field_of_view_corrected,
    channel_axis=channel_axis,
    axes=axes,
    title_1="Original",
    title_2="Corrected",
    title_3="Main Diagonal",
    title_4="Anti Diagonal",
    x_axis="Pixel index",
    y_axis="Intensity",
    normalize=False)


# save graph
if save_graphs:
    graph_saving_name = f"{datetime.datetime.now().strftime(graph_date_format)}{save_file_name_separator}{project_name}{save_file_name_separator}{graph_savingword}{graph_suffix}"
    fig.savefig(os.path.join(graph_saving_directory, graph_saving_name))
    print(f"graph saved as {graph_saving_name} in {graph_saving_directory}")
else:
    print("graph not saved, set save_graphs to True to save the graph")
# Out:
# displaying the result for:
# H7_DENV2_MOI1_30h_fixed_stained_well8_A07p2_C2.ome.tif
# H7_DENV2_MOI1_30h_fixed_stained_well8_A07p2_C2_bg.ome.tif
#
# --- channel 0
# before correction. min value: 434. max value: 6681
# after correction. min value: 45.18611145019531. max value: 6434.77001953125
# --- channel 1
# before correction. min value: 469. max value: 9943
# after correction. min value: 73.0085678100586. max value: 10309.65625
# --- channel 2
# before correction. min value: 469. max value: 12450
# after correction. min value: 83.15321350097656. max value: 14984.7705078125
# --- channel 3
# before correction. min value: 426. max value: 656
# after correction. min value: 31.785259246826172. max value: 256.7115783691406
# --- channel 4
# before correction. min value: 7099. max value: 40998
# after correction. min value: 6834.43310546875. max value: 43250.5234375
# graph saved as 20260320_ACID_illumination_correction.png in Z:\AlessandroUlivi_Data\projects\ACID\develop\260319_illumination_correction\test

# %% [markdown]
# ### Save hyperparameters
#
# Run the following cell.
#
# Don't modify the following cell.

# %%
# # collect hyperparameters in a dictionary

hyperparameter_dict = {

'background_function_strategy':background_function_strategy,
'background_directory':background_directory,
'metadata_directory':metadata_directory,
'fov_directory':fov_directory,
'output_directory':output_directory,
'metadata_file_name':metadata_file_name,
'background_function_timestamp':background_function_timestamp,
'save_graphs':save_graphs,
'graph_saving_directory':graph_saving_directory,
'is_train_column':is_train_column,
'test_val':test_val,
'default_bg_funct_file_target':default_bg_funct_file_target,
'default_bg_funct_file_exclude':default_bg_funct_file_exclude,
'background_from_file_name':background_from_file_name,
'background_default_separator':background_default_separator,
'background_default_date_position':background_default_date_position,
'background_default_date_format':background_default_date_format,
'background_default_reverse':background_default_reverse,
'background_default_assert_file_number':background_default_assert_file_number,
'background_default_number_of_files_expected':background_default_number_of_files_expected,
'default_metadata_file_target':default_metadata_file_target,
'default_metadata_file_exclude':default_metadata_file_exclude,
'metadata_from_file_name':metadata_from_file_name,
'metadata_default_separator':metadata_default_separator,
'metadata_default_date_position':metadata_default_date_position,
'metadata_default_date_format':metadata_default_date_format,
'metadata_default_reverse':metadata_default_reverse,
'channel_axis':channel_axis,
'method':method,
'offset':offset,
'epsilon':epsilon,
'output_dtype':output_dtype,
'working_dtype':working_dtype,
'rescale_background':rescale_background,
'clip_corrected_image':clip_corrected_image,
'min_clip_value':min_clip_value,
'max_clip_value':max_clip_value,
'offset_background':offset_background,
'zero_kwargs':zero_kwargs,
'verbose':verbose,
'fov_column_name':fov_column_name,
'well_column_name':well_column_name,
'gridpos_column_name':gridpos_column_name,
'null_value':null_value,
'proc_img_meta_date_name':proc_img_meta_date_name,
'processing_date_format':processing_date_format,
'proc_img_meta_dtype_name':proc_img_meta_dtype_name,
'illum_corr_method_metadata_entry':illum_corr_method_metadata_entry,
'illum_corr_offset_metadata_entry':illum_corr_offset_metadata_entry,
'illum_corr_rescale_metadata_entry':illum_corr_rescale_metadata_entry,
'illum_corr_clipping_metadata_entry':illum_corr_clipping_metadata_entry,
'illum_corr_clip_min_value_metadata_entry':illum_corr_clip_min_value_metadata_entry,
'illum_corr_clip_max_value_metadata_entry':illum_corr_clip_max_value_metadata_entry,
'illum_corr_offset_background_metadata_entry':illum_corr_offset_background_metadata_entry,
'photometric':photometric,
'save_imagej_compatible':save_imagej_compatible,
'column_name_separator':column_name_separator,
'ch_name_separator':ch_name_separator,
'illum_correct_df_date_clm_name':illum_correct_df_date_clm_name,
'illum_correct_df_meta_date_format':illum_correct_df_meta_date_format,
'illum_correct_df_file_name_clm_name':illum_correct_df_file_name_clm_name,
'illum_correct_df_method_clm_name':illum_correct_df_method_clm_name,
'illum_correct_df_offset_clm_name':illum_correct_df_offset_clm_name,
'illum_correct_df_rescale_clm_name':illum_correct_df_rescale_clm_name,
'illum_correct_df_clipping_clm_name':illum_correct_df_clipping_clm_name,
'illum_correct_df_clip_min_value_clm_name':illum_correct_df_clip_min_value_clm_name,
'illum_correct_df_clip_max_value_clm_name':illum_correct_df_clip_max_value_clm_name,
'illum_correct_df_offset_background_clm_name':illum_correct_df_offset_background_clm_name,
'save_file_name_separator':save_file_name_separator,
'project_name':project_name,
'save_csv_index':save_csv_index,
'fov_illumin_corrected_savingword':fov_illumin_corrected_savingword,
'ome_suffix':ome_suffix,
'metadata_savingword':metadata_savingword,
'metadata_file_suffix':metadata_file_suffix,
'metadata_date_format':metadata_date_format,
'hyperparameters_date_format':hyperparameters_date_format,
'hyperparameters_savingword':hyperparameters_savingword,
'hyperparameters_file_suffix':hyperparameters_file_suffix,
'graph_date_format':graph_date_format,
'graph_suffix':graph_suffix,
'graph_savingword':graph_savingword,
'secondary_output_directory':secondary_output_directory,
'exist_ok':exist_ok

}



# transform the hyperparameter_dict in a pandas series
hyperparameter_series = pd.Series(hyperparameter_dict)

# save hyperparamters
hyperparameter_saving_name = f"{datetime.datetime.now().strftime(hyperparameters_date_format)}{save_file_name_separator}{project_name}{save_file_name_separator}{hyperparameters_savingword}{save_file_name_separator}{hyperparameters_file_suffix}"
hyperparameter_series.to_csv(os.path.join(secondary_output_directory,hyperparameter_saving_name), index=save_csv_index)
